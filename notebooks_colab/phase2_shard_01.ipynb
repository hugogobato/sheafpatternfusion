# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 01/8
# Jobs: 197. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
import pathlib
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00197_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [], [0, 2]]}, "draw_seed": 39970901, "tag": "n3"}, {"iid": "n3_s00232_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 2], []]}, "draw_seed": 43470901, "tag": "n3"}, {"iid": "n3_s00264_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0], []]}, "draw_seed": 46670901, "tag": "n3"}, {"iid": "n3_s00284_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1], [2]]}, "draw_seed": 48670901, "tag": "n3"}, {"iid": "n3_s00300_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 2], [2]]}, "draw_seed": 50270901, "tag": "n3"}, {"iid": "n3_s00329_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0], [0]]}, "draw_seed": 53170901, "tag": "n3"}, {"iid": "n3_s00346_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0, 1], [1]]}, "draw_seed": 54870901, "tag": "n3"}, {"iid": "n3_s00375_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [1, 2], [0, 1, 2]]}, "draw_seed": 57770901, "tag": "n3"}, {"iid": "n3_s00401_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [1], [0]]}, "draw_seed": 60370901, "tag": "n3"}, {"iid": "n3_s00418_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [2], [1]]}, "draw_seed": 62070901, "tag": "n3"}, {"iid": "n3_s00454_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1, 2], [], [1, 2]]}, "draw_seed": 65670901, "tag": "n3"}, {"iid": "n3_s00479_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1, 2], [0, 1], [0, 1, 2]]}, "draw_seed": 68170901, "tag": "n3"}, {"iid": "n3_s00500_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1, 2], [1, 2], [2]]}, "draw_seed": 70270901, "tag": "n3"}, {"iid": "n3_s00529_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[], [1], [0]]}, "draw_seed": 73170901, "tag": "n3"}, {"iid": "n3_s00549_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[], [2], [0, 2]]}, "draw_seed": 75170901, "tag": "n3"}, {"iid": "n3_s00577_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [], [0]]}, "draw_seed": 77970901, "tag": "n3"}, {"iid": "n3_s00591_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [0], [0, 1, 2]]}, "draw_seed": 79370901, "tag": "n3"}, {"iid": "n3_s00611_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [2], [0, 1]]}, "draw_seed": 81370901, "tag": "n3"}, {"iid": "n3_s00630_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [1, 2], [1, 2]]}, "draw_seed": 83270901, "tag": "n3"}, {"iid": "n3_s00651_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [0], [0, 1]]}, "draw_seed": 85370901, "tag": "n3"}, {"iid": "n3_s00666_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [0, 1], [1]]}, "draw_seed": 86870901, "tag": "n3"}, {"iid": "n3_s00679_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [2], [0, 1, 2]]}, "draw_seed": 88170901, "tag": "n3"}, {"iid": "n3_s00692_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [1, 2], [2]]}, "draw_seed": 89470901, "tag": "n3"}, {"iid": "n3_s00714_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1], [0], [1]]}, "draw_seed": 91670901, "tag": "n3"}, {"iid": "n3_s00735_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1], [0, 1], [0, 1, 2]]}, "draw_seed": 93770901, "tag": "n3"}, {"iid": "n3_s00759_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1], [1, 2], [0, 1, 2]]}, "draw_seed": 96170901, "tag": "n3"}, {"iid": "n3_s00790_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[2], [1], [1, 2]]}, "draw_seed": 99270901, "tag": "n3"}, {"iid": "n3_s00818_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[2], [1, 2], [1]]}, "draw_seed": 102070901, "tag": "n3"}, {"iid": "n3_s00843_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 2], [0], [0, 1]]}, "draw_seed": 104570901, "tag": "n3"}, {"iid": "n3_s00867_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 2], [2], [0, 1]]}, "draw_seed": 106970901, "tag": "n3"}, {"iid": "n3_s00891_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 2], [0, 1, 2], [0, 1]]}, "draw_seed": 109370901, "tag": "n3"}, {"iid": "n3_s00908_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1, 2], [0], [2]]}, "draw_seed": 111070901, "tag": "n3"}, {"iid": "n3_s00948_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1, 2], [1, 2], [2]]}, "draw_seed": 115070901, "tag": "n3"}, {"iid": "n3_s00964_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [], [2]]}, "draw_seed": 116670901, "tag": "n3"}, {"iid": "n3_s00989_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1], [0, 2]]}, "draw_seed": 119170901, "tag": "n3"}, {"iid": "n3_s01003_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [0, 2], [0, 1]]}, "draw_seed": 120570901, "tag": "n3"}, {"iid": "n3_s01021_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1, 2], [0, 2]]}, "draw_seed": 122370901, "tag": "n3"}, {"iid": "n3_s01044_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[], [1], [2]]}, "draw_seed": 124670901, "tag": "n3"}, {"iid": "n3_s01075_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[], [1, 2], [0, 1]]}, "draw_seed": 127770901, "tag": "n3"}, {"iid": "n3_s01099_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0], [0], [0, 1]]}, "draw_seed": 130170901, "tag": "n3"}, {"iid": "n3_s01117_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0], [0, 1], [0, 2]]}, "draw_seed": 131970901, "tag": "n3"}, {"iid": "n3_s01146_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0], [0, 1, 2], [1]]}, "draw_seed": 134870901, "tag": "n3"}, {"iid": "n3_s01165_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1], [0], [0, 2]]}, "draw_seed": 136770901, "tag": "n3"}, {"iid": "n3_s01193_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1], [0, 2], [0]]}, "draw_seed": 139570901, "tag": "n3"}, {"iid": "n3_s01212_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1], [0, 1, 2], [2]]}, "draw_seed": 141470901, "tag": "n3"}, {"iid": "n3_s01233_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1], [1], [0]]}, "draw_seed": 143570901, "tag": "n3"}, {"iid": "n3_s01257_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1], [0, 2], [0]]}, "draw_seed": 145970901, "tag": "n3"}, {"iid": "n3_s01294_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[2], [0], [1, 2]]}, "draw_seed": 149670901, "tag": "n3"}, {"iid": "n3_s01326_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[2], [0, 2], [1, 2]]}, "draw_seed": 152870901, "tag": "n3"}, {"iid": "n3_s01357_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 2], [0], [0, 2]]}, "draw_seed": 155970901, "tag": "n3"}, {"iid": "n3_s01374_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 2], [0, 1], [1, 2]]}, "draw_seed": 157670901, "tag": "n3"}, {"iid": "n3_s01398_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 2], [1, 2], [1, 2]]}, "draw_seed": 160070901, "tag": "n3"}, {"iid": "n3_s01417_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1, 2], [0], [0]]}, "draw_seed": 161970901, "tag": "n3"}, {"iid": "n3_s01439_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1, 2], [0, 1], [0, 1, 2]]}, "draw_seed": 164170901, "tag": "n3"}, {"iid": "n3_s01458_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1, 2], [1, 2], [1]]}, "draw_seed": 166070901, "tag": "n3"}, {"iid": "n3_s01479_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1, 2], [], [0, 1, 2]]}, "draw_seed": 168170901, "tag": "n3"}, {"iid": "n3_s01500_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1, 2], [0, 1], [2]]}, "draw_seed": 170270901, "tag": "n3"}, {"iid": "n3_s01517_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 2]]}, "draw_seed": 171970901, "tag": "n3"}, {"iid": "n3_s01537_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[], [], [0]]}, "draw_seed": 173970901, "tag": "n3"}, {"iid": "n3_s01568_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[], [2], []]}, "draw_seed": 177070901, "tag": "n3"}, {"iid": "n3_s01581_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[], [0, 2], [0, 2]]}, "draw_seed": 178370901, "tag": "n3"}, {"iid": "n3_s01607_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0], [], [0, 1, 2]]}, "draw_seed": 180970901, "tag": "n3"}, {"iid": "n3_s01644_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0], [0, 2], [2]]}, "draw_seed": 184670901, "tag": "n3"}, {"iid": "n3_s01670_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1], [], [1, 2]]}, "draw_seed": 187270901, "tag": "n3"}, {"iid": "n3_s01696_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1], [2], []]}, "draw_seed": 189870901, "tag": "n3"}, {"iid": "n3_s01729_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1], [], [0]]}, "draw_seed": 193170901, "tag": "n3"}, {"iid": "n3_s01753_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1], [0]]}, "draw_seed": 195570901, "tag": "n3"}, {"iid": "n3_s01789_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], [0, 2]]}, "draw_seed": 199170901, "tag": "n3"}, {"iid": "n3_s01821_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[2], [0, 1], [0, 2]]}, "draw_seed": 202370901, "tag": "n3"}, {"iid": "n3_s01840_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[2], [1, 2], []]}, "draw_seed": 204270901, "tag": "n3"}, {"iid": "n3_s01858_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 2], [], [1]]}, "draw_seed": 206070901, "tag": "n3"}, {"iid": "n3_s01878_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 2], [1], [1, 2]]}, "draw_seed": 208070901, "tag": "n3"}, {"iid": "n3_s01901_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 2], [0, 2], [0, 2]]}, "draw_seed": 210370901, "tag": "n3"}, {"iid": "n3_s01920_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1, 2], [], []]}, "draw_seed": 212270901, "tag": "n3"}, {"iid": "n3_s01949_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1], [0, 2]]}, "draw_seed": 215170901, "tag": "n3"}, {"iid": "n3_s01972_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [2]]}, "draw_seed": 217470901, "tag": "n3"}, {"iid": "n3_s01994_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0], [1]]}, "draw_seed": 219670901, "tag": "n3"}, {"iid": "n3_s02020_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1, 2], [2], [2]]}, "draw_seed": 222270901, "tag": "n3"}, {"iid": "n3_s02051_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[], [], [0, 1]]}, "draw_seed": 225370901, "tag": "n3"}, {"iid": "n3_s02078_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[], [0, 1], [1, 2]]}, "draw_seed": 228070901, "tag": "n3"}, {"iid": "n3_s02100_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[], [1, 2], [2]]}, "draw_seed": 230270901, "tag": "n3"}, {"iid": "n3_s02120_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0], [0], []]}, "draw_seed": 232270901, "tag": "n3"}, {"iid": "n3_s02153_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0], [0, 2], [0]]}, "draw_seed": 235570901, "tag": "n3"}, {"iid": "n3_s02178_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1], [], [1]]}, "draw_seed": 238070901, "tag": "n3"}, {"iid": "n3_s02217_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1], [0, 2], [0]]}, "draw_seed": 241970901, "tag": "n3"}, {"iid": "n3_s02238_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1], [0, 1, 2], [1, 2]]}, "draw_seed": 244070901, "tag": "n3"}, {"iid": "n3_s02266_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1], [0, 1], [1]]}, "draw_seed": 246870901, "tag": "n3"}, {"iid": "n3_s02293_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1], [1, 2], [0, 2]]}, "draw_seed": 249570901, "tag": "n3"}, {"iid": "n3_s02311_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[2], [], [0, 1, 2]]}, "draw_seed": 251370901, "tag": "n3"}, {"iid": "n3_s02343_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[2], [2], [0, 1, 2]]}, "draw_seed": 254570901, "tag": "n3"}, {"iid": "n3_s02374_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 2], [], [1, 2]]}, "draw_seed": 257670901, "tag": "n3"}, {"iid": "n3_s02393_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 2], [0, 1], [0]]}, "draw_seed": 259570901, "tag": "n3"}, {"iid": "n3_s02415_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 2], [0, 2], [0, 1, 2]]}, "draw_seed": 261770901, "tag": "n3"}, {"iid": "n3_s02443_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1, 2], [0], [0, 1]]}, "draw_seed": 264570901, "tag": "n3"}, {"iid": "n3_s02456_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1, 2], [0, 1], []]}, "draw_seed": 265870901, "tag": "n3"}, {"iid": "n3_s02482_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1, 2], [1, 2], [1]]}, "draw_seed": 268470901, "tag": "n3"}, {"iid": "n3_s02514_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1, 2], [1], [1]]}, "draw_seed": 271670901, "tag": "n3"}, {"iid": "n3_s02531_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1, 2], [2], [0, 1]]}, "draw_seed": 273370901, "tag": "n3"}, {"iid": "n3_s02551_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1, 2], [1, 2], [0, 1, 2]]}, "draw_seed": 275370901, "tag": "n3"}, {"iid": "n3_s02576_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [1], []]}, "draw_seed": 277870901, "tag": "n3"}, {"iid": "n3_s02589_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [0, 1], [0, 2]]}, "draw_seed": 279170901, "tag": "n3"}, {"iid": "n3_s02620_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [0, 1, 2], [2]]}, "draw_seed": 282270901, "tag": "n3"}, {"iid": "n3_s02645_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [1], [0, 2]]}, "draw_seed": 284770901, "tag": "n3"}, {"iid": "n3_s02674_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [1, 2], [1]]}, "draw_seed": 287670901, "tag": "n3"}, {"iid": "n3_s02710_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [1], [1, 2]]}, "draw_seed": 291270901, "tag": "n3"}, {"iid": "n3_s02729_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [0, 2], [0]]}, "draw_seed": 293170901, "tag": "n3"}, {"iid": "n3_s02756_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [], [2]]}, "draw_seed": 295870901, "tag": "n3"}, {"iid": "n3_s02781_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0, 1], [0, 2]]}, "draw_seed": 298370901, "tag": "n3"}, {"iid": "n3_s02793_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0, 2], [0]]}, "draw_seed": 299570901, "tag": "n3"}, {"iid": "n3_s02815_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 301770901, "tag": "n3"}, {"iid": "n3_s02838_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [1], [1, 2]]}, "draw_seed": 304070901, "tag": "n3"}, {"iid": "n3_s02871_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [1, 2], [0, 1, 2]]}, "draw_seed": 307370901, "tag": "n3"}, {"iid": "n3_s02886_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [], [1, 2]]}, "draw_seed": 308870901, "tag": "n3"}, {"iid": "n3_s02900_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [1], [2]]}, "draw_seed": 310270901, "tag": "n3"}, {"iid": "n3_s02929_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [1, 2], [0]]}, "draw_seed": 313170901, "tag": "n3"}, {"iid": "n3_s02964_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [1], [2]]}, "draw_seed": 316670901, "tag": "n3"}, {"iid": "n3_s02989_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [0, 2], [0, 2]]}, "draw_seed": 319170901, "tag": "n3"}, {"iid": "n3_s03012_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [], [2]]}, "draw_seed": 321470901, "tag": "n3"}, {"iid": "n3_s03031_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [1], [0, 1, 2]]}, "draw_seed": 323370901, "tag": "n3"}, {"iid": "n3_s03067_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1, 2], [0, 1]]}, "draw_seed": 326970901, "tag": "n3"}, {"iid": "n3_s03091_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [1], [0, 1]]}, "draw_seed": 329370901, "tag": "n3"}, {"iid": "n3_s03115_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0, 2], [0, 1]]}, "draw_seed": 331770901, "tag": "n3"}, {"iid": "n3_s03144_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0], []]}, "draw_seed": 334670901, "tag": "n3"}, {"iid": "n3_s03159_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1], [0, 1, 2]]}, "draw_seed": 336170901, "tag": "n3"}, {"iid": "n3_s03179_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0, 2], [0, 1]]}, "draw_seed": 338170901, "tag": "n3"}, {"iid": "n3_s03205_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [], [0, 2]]}, "draw_seed": 340770901, "tag": "n3"}, {"iid": "n3_s03221_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [1], [0, 2]]}, "draw_seed": 342370901, "tag": "n3"}, {"iid": "n3_s03242_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [0, 2], [1]]}, "draw_seed": 344470901, "tag": "n3"}, {"iid": "n3_s03270_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [], [1, 2]]}, "draw_seed": 347270901, "tag": "n3"}, {"iid": "n3_s03290_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0, 1], [1]]}, "draw_seed": 349270901, "tag": "n3"}, {"iid": "n3_s03311_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0, 2], [0, 1, 2]]}, "draw_seed": 351370901, "tag": "n3"}, {"iid": "n3_s03337_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0], [0]]}, "draw_seed": 353970901, "tag": "n3"}, {"iid": "n3_s03358_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 1], [1, 2]]}, "draw_seed": 356070901, "tag": "n3"}, {"iid": "n3_s03375_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 2], [0, 1, 2]]}, "draw_seed": 357770901, "tag": "n3"}, {"iid": "n3_s03398_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [], [1, 2]]}, "draw_seed": 360070901, "tag": "n3"}, {"iid": "n3_s03423_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1], [0, 1, 2]]}, "draw_seed": 362570901, "tag": "n3"}, {"iid": "n3_s03438_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 2], [1, 2]]}, "draw_seed": 364070901, "tag": "n3"}, {"iid": "n3_s03452_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1, 2], [2]]}, "draw_seed": 365470901, "tag": "n3"}, {"iid": "n3_s03481_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1], [0]]}, "draw_seed": 368370901, "tag": "n3"}, {"iid": "n3_s03497_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 2], [0]]}, "draw_seed": 369970901, "tag": "n3"}, {"iid": "n3_s03519_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 372170901, "tag": "n3"}, {"iid": "n3_s03531_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0], [0, 1]]}, "draw_seed": 373370901, "tag": "n3"}, {"iid": "n3_s03552_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [2], []]}, "draw_seed": 375470901, "tag": "n3"}, {"iid": "n3_s03573_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1, 2], [0, 2]]}, "draw_seed": 377570901, "tag": "n3"}, {"iid": "n3_s03600_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [1], []]}, "draw_seed": 380270901, "tag": "n3"}, {"iid": "n3_s03631_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 2], [0, 1, 2]]}, "draw_seed": 383370901, "tag": "n3"}, {"iid": "n3_s03659_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0], [0, 1]]}, "draw_seed": 386170901, "tag": "n3"}, {"iid": "n3_s03678_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1], [1, 2]]}, "draw_seed": 388070901, "tag": "n3"}, {"iid": "n3_s03706_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1, 2], [1]]}, "draw_seed": 390870901, "tag": "n3"}, {"iid": "n3_s03726_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0], [1, 2]]}, "draw_seed": 392870901, "tag": "n3"}, {"iid": "n3_s03753_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 2], [0]]}, "draw_seed": 395570901, "tag": "n3"}, {"iid": "n3_s03769_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1, 2], [0]]}, "draw_seed": 397170901, "tag": "n3"}, {"iid": "n3_s03793_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [1], [0]]}, "draw_seed": 399570901, "tag": "n3"}, {"iid": "n3_s03818_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 2], [1]]}, "draw_seed": 402070901, "tag": "n3"}, {"iid": "n3_s03835_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], [0, 1]]}, "draw_seed": 403770901, "tag": "n3"}, {"iid": "n3_s03853_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0], [0, 2]]}, "draw_seed": 405570901, "tag": "n3"}, {"iid": "n3_s03875_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [2], [0, 1]]}, "draw_seed": 407770901, "tag": "n3"}, {"iid": "n3_s03902_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1, 2], [1, 2]]}, "draw_seed": 410470901, "tag": "n3"}, {"iid": "n3_s03918_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0], [1, 2]]}, "draw_seed": 412070901, "tag": "n3"}, {"iid": "n3_s03934_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1], [1, 2]]}, "draw_seed": 413670901, "tag": "n3"}, {"iid": "n3_s03953_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1, 2], [0]]}, "draw_seed": 415570901, "tag": "n3"}, {"iid": "n3_s03976_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0], []]}, "draw_seed": 417870901, "tag": "n3"}, {"iid": "n3_s03991_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1], [0, 1, 2]]}, "draw_seed": 419370901, "tag": "n3"}, {"iid": "n3_s04011_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 2], [0, 1]]}, "draw_seed": 421370901, "tag": "n3"}, {"iid": "n3_s04029_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1, 2], [0, 2]]}, "draw_seed": 423170901, "tag": "n3"}, {"iid": "n3_s04044_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0], [2]]}, "draw_seed": 424670901, "tag": "n3"}, {"iid": "n3_s04062_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 1], [1, 2]]}, "draw_seed": 426470901, "tag": "n3"}, {"iid": "n3_s04084_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1, 2], [2]]}, "draw_seed": 428670901, "tag": "n3"}, {"iid": "named_mar_textbook_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [0]]}, "draw_seed": 20286455, "tag": "named"}, {"iid": "named_mediated_mnar_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[1], [0, 1]]}, "draw_seed": 20302011, "tag": "named"}, {"iid": "named_self_censor_v1_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[0], []]}, "draw_seed": 20325341, "tag": "named"}, {"iid": "named_three_var_mixed_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0], [2]]}, "draw_seed": 20348671, "tag": "named"}, {"iid": "n4_r0005_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 1, 2]}, "r_parents": [[1, 2], [0, 1], [0, 3], [0, 1]]}, "draw_seed": 25271056, "tag": "n4"}, {"iid": "n4_r0013_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0, 2]}, "r_parents": [[2], [2, 3], [1, 2], [0, 3]]}, "draw_seed": 25271304, "tag": "n4"}, {"iid": "n4_r0021_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": []}, "r_parents": [[0, 1], [0, 1], [1, 3], [0]]}, "draw_seed": 25271552, "tag": "n4"}, {"iid": "n4_r0029_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": []}, "r_parents": [[1], [0, 1, 2, 3], [3], [0, 2, 3]]}, "draw_seed": 25271800, "tag": "n4"}, {"iid": "n4_r0037_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0]}, "r_parents": [[1, 2, 3], [1, 2, 3], [2], [1]]}, "draw_seed": 25272048, "tag": "n4"}, {"iid": "n4_r0045_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 1]}, "r_parents": [[0, 3], [2], [1, 2], [0]]}, "draw_seed": 25272296, "tag": "n4"}, {"iid": "n4_r0053_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 2]}, "r_parents": [[1, 2], [0, 1], [0, 1, 2, 3], [0]]}, "draw_seed": 25272544, "tag": "n4"}, {"iid": "n4_r0061_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1]}, "r_parents": [[0, 3], [3], [0, 1, 2], [0, 3]]}, "draw_seed": 25272792, "tag": "n4"}, {"iid": "n4_r0069_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [1]}, "r_parents": [[1, 3], [2, 3], [0, 1, 2, 3], [1, 2]]}, "draw_seed": 25273040, "tag": "n4"}, {"iid": "n4_r0077_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1]}, "r_parents": [[1], [0, 3], [2, 3], [1, 3]]}, "draw_seed": 25273288, "tag": "n4"}, {"iid": "n4_r0085_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[0, 3], [1, 3], [0, 2, 3], [1, 2, 3]]}, "draw_seed": 25273536, "tag": "n4"}, {"iid": "n4_r0093_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [1, 2]}, "r_parents": [[0, 1, 3], [1, 2, 3], [], [1]]}, "draw_seed": 25273784, "tag": "n4"}, {"iid": "n4_r0101_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 1, 2]}, "r_parents": [[0, 2], [0, 1, 2, 3], [3], [0, 3]]}, "draw_seed": 25274032, "tag": "n4"}, {"iid": "n4_r0109_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 2]}, "r_parents": [[0, 2, 3], [0], [0, 2, 3], [0, 2]]}, "draw_seed": 25274280, "tag": "n4"}, {"iid": "n4_r0117_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": []}, "r_parents": [[3], [1, 2, 3], [0, 1], [1, 2, 3]]}, "draw_seed": 25274528, "tag": "n4"}, {"iid": "n4_r0125_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1, 2]}, "r_parents": [[1, 2, 3], [0, 1, 2], [0], [0, 3]]}, "draw_seed": 25274776, "tag": "n4"}, {"iid": "n4_r0133_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [2]}, "r_parents": [[0, 1, 2], [0], [2, 3], [0]]}, "draw_seed": 25275024, "tag": "n4"}, {"iid": "n4_r0141_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1]}, "r_parents": [[2], [0, 1, 2, 3], [0, 1, 3], [0]]}, "draw_seed": 25275272, "tag": "n4"}, {"iid": "n4_r0149_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [2]}, "r_parents": [[], [0, 1, 2], [0, 1, 2, 3], [0, 1, 3]]}, "draw_seed": 25275520, "tag": "n4"}, {"iid": "n4_r0157_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [2]}, "r_parents": [[0, 2], [1, 2, 3], [1, 2, 3], []]}, "draw_seed": 25275768, "tag": "n4"}, {"iid": "n4_r0165_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1, 2]}, "r_parents": [[1, 2, 3], [2, 3], [0, 1, 2], [0, 2, 3]]}, "draw_seed": 25276016, "tag": "n4"}, {"iid": "n4_r0173_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0, 1]}, "r_parents": [[0, 1], [1], [2], [2, 3]]}, "draw_seed": 25276264, "tag": "n4"}, {"iid": "n4_r0181_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 1]}, "r_parents": [[1, 2, 3], [3], [1], [0, 2]]}, "draw_seed": 25276512, "tag": "n4"}, {"iid": "n4_r0189_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [1, 2]}, "r_parents": [[0, 1, 2, 3], [1], [0, 1, 3], [0, 1, 2, 3]]}, "draw_seed": 25276760, "tag": "n4"}, {"iid": "n4_r0197_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 1, 2]}, "r_parents": [[2], [0, 2, 3], [], [1, 3]]}, "draw_seed": 25277008, "tag": "n4"}]''')
SHARD_IDX = 1
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
