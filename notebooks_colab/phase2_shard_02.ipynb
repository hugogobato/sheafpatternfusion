# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 02/8
# Jobs: 197. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
import pathlib
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00203_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0], [0, 1]]}, "draw_seed": 40570901, "tag": "n3"}, {"iid": "n3_s00233_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 2], [0]]}, "draw_seed": 43570901, "tag": "n3"}, {"iid": "n3_s00265_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0], [0]]}, "draw_seed": 46770901, "tag": "n3"}, {"iid": "n3_s00285_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1], [0, 2]]}, "draw_seed": 48770901, "tag": "n3"}, {"iid": "n3_s00301_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 2], [0, 2]]}, "draw_seed": 50370901, "tag": "n3"}, {"iid": "n3_s00330_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0], [1]]}, "draw_seed": 53270901, "tag": "n3"}, {"iid": "n3_s00347_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0, 1], [0, 1]]}, "draw_seed": 54970901, "tag": "n3"}, {"iid": "n3_s00376_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0, 1, 2], []]}, "draw_seed": 57870901, "tag": "n3"}, {"iid": "n3_s00404_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [1], [2]]}, "draw_seed": 60670901, "tag": "n3"}, {"iid": "n3_s00421_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [2], [0, 2]]}, "draw_seed": 62370901, "tag": "n3"}, {"iid": "n3_s00455_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1, 2], [], [0, 1, 2]]}, "draw_seed": 65770901, "tag": "n3"}, {"iid": "n3_s00487_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1, 2], [2], [0, 1, 2]]}, "draw_seed": 68970901, "tag": "n3"}, {"iid": "n3_s00502_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1, 2], [1, 2], [1, 2]]}, "draw_seed": 70470901, "tag": "n3"}, {"iid": "n3_s00533_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[], [1], [0, 2]]}, "draw_seed": 73570901, "tag": "n3"}, {"iid": "n3_s00552_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[], [0, 2], []]}, "draw_seed": 75470901, "tag": "n3"}, {"iid": "n3_s00581_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [], [0, 2]]}, "draw_seed": 78370901, "tag": "n3"}, {"iid": "n3_s00592_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [1], []]}, "draw_seed": 79470901, "tag": "n3"}, {"iid": "n3_s00612_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [2], [2]]}, "draw_seed": 81470901, "tag": "n3"}, {"iid": "n3_s00631_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0], [1, 2], [0, 1, 2]]}, "draw_seed": 83370901, "tag": "n3"}, {"iid": "n3_s00653_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [0], [0, 2]]}, "draw_seed": 85570901, "tag": "n3"}, {"iid": "n3_s00667_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [0, 1], [0, 1]]}, "draw_seed": 86970901, "tag": "n3"}, {"iid": "n3_s00680_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [0, 2], []]}, "draw_seed": 88270901, "tag": "n3"}, {"iid": "n3_s00694_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1], [1, 2], [1, 2]]}, "draw_seed": 89670901, "tag": "n3"}, {"iid": "n3_s00716_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1], [0], [2]]}, "draw_seed": 91870901, "tag": "n3"}, {"iid": "n3_s00739_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1], [2], [0, 1]]}, "draw_seed": 94170901, "tag": "n3"}, {"iid": "n3_s00762_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1], [0, 1, 2], [1]]}, "draw_seed": 96470901, "tag": "n3"}, {"iid": "n3_s00791_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[2], [1], [0, 1, 2]]}, "draw_seed": 99370901, "tag": "n3"}, {"iid": "n3_s00819_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[2], [1, 2], [0, 1]]}, "draw_seed": 102170901, "tag": "n3"}, {"iid": "n3_s00848_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 2], [1], []]}, "draw_seed": 105070901, "tag": "n3"}, {"iid": "n3_s00871_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 2], [2], [0, 1, 2]]}, "draw_seed": 107370901, "tag": "n3"}, {"iid": "n3_s00892_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 2], [0, 1, 2], [2]]}, "draw_seed": 109470901, "tag": "n3"}, {"iid": "n3_s00922_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1, 2], [0, 1], [1]]}, "draw_seed": 112470901, "tag": "n3"}, {"iid": "n3_s00952_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[1, 2], [0, 1, 2], []]}, "draw_seed": 115470901, "tag": "n3"}, {"iid": "n3_s00969_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [0], [0]]}, "draw_seed": 117170901, "tag": "n3"}, {"iid": "n3_s00990_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1], [1, 2]]}, "draw_seed": 119270901, "tag": "n3"}, {"iid": "n3_s01007_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0]}, "r_parents": [[0, 1, 2], [0, 2], [0, 1, 2]]}, "draw_seed": 120970901, "tag": "n3"}, {"iid": "n3_s01024_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[], [], []]}, "draw_seed": 122670901, "tag": "n3"}, {"iid": "n3_s01048_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[], [0, 1], []]}, "draw_seed": 125070901, "tag": "n3"}, {"iid": "n3_s01076_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[], [1, 2], [2]]}, "draw_seed": 127870901, "tag": "n3"}, {"iid": "n3_s01102_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0], [0], [1, 2]]}, "draw_seed": 130470901, "tag": "n3"}, {"iid": "n3_s01119_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0], [0, 1], [0, 1, 2]]}, "draw_seed": 132170901, "tag": "n3"}, {"iid": "n3_s01148_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0], [0, 1, 2], [2]]}, "draw_seed": 135070901, "tag": "n3"}, {"iid": "n3_s01166_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1], [0], [1, 2]]}, "draw_seed": 136870901, "tag": "n3"}, {"iid": "n3_s01199_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1], [0, 2], [0, 1, 2]]}, "draw_seed": 140170901, "tag": "n3"}, {"iid": "n3_s01215_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 141770901, "tag": "n3"}, {"iid": "n3_s01234_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1], [1], [1]]}, "draw_seed": 143670901, "tag": "n3"}, {"iid": "n3_s01258_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1], [0, 2], [1]]}, "draw_seed": 146070901, "tag": "n3"}, {"iid": "n3_s01295_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[2], [0], [0, 1, 2]]}, "draw_seed": 149770901, "tag": "n3"}, {"iid": "n3_s01330_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[2], [1, 2], [1]]}, "draw_seed": 153270901, "tag": "n3"}, {"iid": "n3_s01358_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 2], [0], [1, 2]]}, "draw_seed": 156070901, "tag": "n3"}, {"iid": "n3_s01376_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 2], [2], []]}, "draw_seed": 157870901, "tag": "n3"}, {"iid": "n3_s01399_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 2], [1, 2], [0, 1, 2]]}, "draw_seed": 160170901, "tag": "n3"}, {"iid": "n3_s01420_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1, 2], [0], [2]]}, "draw_seed": 162270901, "tag": "n3"}, {"iid": "n3_s01441_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1, 2], [2], [0]]}, "draw_seed": 164370901, "tag": "n3"}, {"iid": "n3_s01459_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[1, 2], [1, 2], [0, 1]]}, "draw_seed": 166170901, "tag": "n3"}, {"iid": "n3_s01480_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1, 2], [0], []]}, "draw_seed": 168270901, "tag": "n3"}, {"iid": "n3_s01503_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1, 2], [0, 1], [0, 1, 2]]}, "draw_seed": 170570901, "tag": "n3"}, {"iid": "n3_s01520_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [1]}, "r_parents": [[0, 1, 2], [1, 2], []]}, "draw_seed": 172270901, "tag": "n3"}, {"iid": "n3_s01541_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[], [], [0, 2]]}, "draw_seed": 174370901, "tag": "n3"}, {"iid": "n3_s01569_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[], [2], [0]]}, "draw_seed": 177170901, "tag": "n3"}, {"iid": "n3_s01583_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[], [0, 2], [0, 1, 2]]}, "draw_seed": 178570901, "tag": "n3"}, {"iid": "n3_s01615_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0], [0], [0, 1, 2]]}, "draw_seed": 181770901, "tag": "n3"}, {"iid": "n3_s01650_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0], [1, 2], [1]]}, "draw_seed": 185270901, "tag": "n3"}, {"iid": "n3_s01673_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1], [0], [0]]}, "draw_seed": 187570901, "tag": "n3"}, {"iid": "n3_s01705_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1], [0, 2], [0]]}, "draw_seed": 190770901, "tag": "n3"}, {"iid": "n3_s01730_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1], [], [1]]}, "draw_seed": 193270901, "tag": "n3"}, {"iid": "n3_s01754_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1], [1]]}, "draw_seed": 195670901, "tag": "n3"}, {"iid": "n3_s01791_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 199370901, "tag": "n3"}, {"iid": "n3_s01823_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[2], [0, 1], [0, 1, 2]]}, "draw_seed": 202570901, "tag": "n3"}, {"iid": "n3_s01842_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[2], [1, 2], [1]]}, "draw_seed": 204470901, "tag": "n3"}, {"iid": "n3_s01865_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 2], [0], [0]]}, "draw_seed": 206770901, "tag": "n3"}, {"iid": "n3_s01879_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 2], [1], [0, 1, 2]]}, "draw_seed": 208170901, "tag": "n3"}, {"iid": "n3_s01902_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 2], [0, 2], [1, 2]]}, "draw_seed": 210470901, "tag": "n3"}, {"iid": "n3_s01922_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1, 2], [], [1]]}, "draw_seed": 212470901, "tag": "n3"}, {"iid": "n3_s01952_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1, 2], [2], []]}, "draw_seed": 215470901, "tag": "n3"}, {"iid": "n3_s01974_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [1, 2]]}, "draw_seed": 217670901, "tag": "n3"}, {"iid": "n3_s01996_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0], [2]]}, "draw_seed": 219870901, "tag": "n3"}, {"iid": "n3_s02027_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 1]]}, "draw_seed": 222970901, "tag": "n3"}, {"iid": "n3_s02057_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[], [0], [0]]}, "draw_seed": 225970901, "tag": "n3"}, {"iid": "n3_s02079_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[], [0, 1], [0, 1, 2]]}, "draw_seed": 228170901, "tag": "n3"}, {"iid": "n3_s02101_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[], [1, 2], [0, 2]]}, "draw_seed": 230370901, "tag": "n3"}, {"iid": "n3_s02127_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0], [0], [0, 1, 2]]}, "draw_seed": 232970901, "tag": "n3"}, {"iid": "n3_s02158_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0], [0, 2], [1, 2]]}, "draw_seed": 236070901, "tag": "n3"}, {"iid": "n3_s02181_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1], [], [0, 2]]}, "draw_seed": 238370901, "tag": "n3"}, {"iid": "n3_s02218_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1], [0, 2], [1]]}, "draw_seed": 242070901, "tag": "n3"}, {"iid": "n3_s02243_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1], [], [0, 1]]}, "draw_seed": 244570901, "tag": "n3"}, {"iid": "n3_s02270_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1], [0, 1], [1, 2]]}, "draw_seed": 247270901, "tag": "n3"}, {"iid": "n3_s02294_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1], [1, 2], [1, 2]]}, "draw_seed": 249670901, "tag": "n3"}, {"iid": "n3_s02317_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[2], [0], [0, 2]]}, "draw_seed": 251970901, "tag": "n3"}, {"iid": "n3_s02347_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[2], [0, 2], [0, 1]]}, "draw_seed": 254970901, "tag": "n3"}, {"iid": "n3_s02376_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 2], [0], []]}, "draw_seed": 257870901, "tag": "n3"}, {"iid": "n3_s02397_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 2], [0, 1], [0, 2]]}, "draw_seed": 259970901, "tag": "n3"}, {"iid": "n3_s02426_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 2], [0, 1, 2], [1]]}, "draw_seed": 262870901, "tag": "n3"}, {"iid": "n3_s02444_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1, 2], [0], [2]]}, "draw_seed": 264670901, "tag": "n3"}, {"iid": "n3_s02458_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1, 2], [0, 1], [1]]}, "draw_seed": 266070901, "tag": "n3"}, {"iid": "n3_s02484_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[1, 2], [1, 2], [2]]}, "draw_seed": 268670901, "tag": "n3"}, {"iid": "n3_s02519_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1, 2], [1], [0, 1, 2]]}, "draw_seed": 272170901, "tag": "n3"}, {"iid": "n3_s02533_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1, 2], [2], [0, 2]]}, "draw_seed": 273570901, "tag": "n3"}, {"iid": "n3_s02553_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": []}, "r_parents": [[0, 1, 2], [0, 1, 2], [0]]}, "draw_seed": 275570901, "tag": "n3"}, {"iid": "n3_s02577_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [1], [0]]}, "draw_seed": 277970901, "tag": "n3"}, {"iid": "n3_s02590_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [0, 1], [1, 2]]}, "draw_seed": 279270901, "tag": "n3"}, {"iid": "n3_s02623_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 282570901, "tag": "n3"}, {"iid": "n3_s02648_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [0, 1], []]}, "draw_seed": 285070901, "tag": "n3"}, {"iid": "n3_s02675_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [1, 2], [0, 1]]}, "draw_seed": 287770901, "tag": "n3"}, {"iid": "n3_s02715_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [0, 1], [0, 1]]}, "draw_seed": 291770901, "tag": "n3"}, {"iid": "n3_s02735_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [0, 2], [0, 1, 2]]}, "draw_seed": 293770901, "tag": "n3"}, {"iid": "n3_s02760_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0], []]}, "draw_seed": 296270901, "tag": "n3"}, {"iid": "n3_s02782_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0, 1], [1, 2]]}, "draw_seed": 298470901, "tag": "n3"}, {"iid": "n3_s02795_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0, 2], [0, 1]]}, "draw_seed": 299770901, "tag": "n3"}, {"iid": "n3_s02817_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [], [0]]}, "draw_seed": 301970901, "tag": "n3"}, {"iid": "n3_s02839_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [1], [0, 1, 2]]}, "draw_seed": 304170901, "tag": "n3"}, {"iid": "n3_s02872_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [0, 1, 2], []]}, "draw_seed": 307470901, "tag": "n3"}, {"iid": "n3_s02888_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [0], []]}, "draw_seed": 309070901, "tag": "n3"}, {"iid": "n3_s02914_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [2], [1]]}, "draw_seed": 311670901, "tag": "n3"}, {"iid": "n3_s02933_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [1, 2], [0, 2]]}, "draw_seed": 313570901, "tag": "n3"}, {"iid": "n3_s02971_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [0, 1], [0, 1]]}, "draw_seed": 317370901, "tag": "n3"}, {"iid": "n3_s02992_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [1, 2], []]}, "draw_seed": 319470901, "tag": "n3"}, {"iid": "n3_s03013_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [], [0, 2]]}, "draw_seed": 321570901, "tag": "n3"}, {"iid": "n3_s03034_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1], [1]]}, "draw_seed": 323670901, "tag": "n3"}, {"iid": "n3_s03069_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1, 2], [0, 2]]}, "draw_seed": 327170901, "tag": "n3"}, {"iid": "n3_s03098_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0, 1], [1]]}, "draw_seed": 330070901, "tag": "n3"}, {"iid": "n3_s03126_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [1, 2], [1, 2]]}, "draw_seed": 332870901, "tag": "n3"}, {"iid": "n3_s03145_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0], [0]]}, "draw_seed": 334770901, "tag": "n3"}, {"iid": "n3_s03161_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0, 1], [0]]}, "draw_seed": 336370901, "tag": "n3"}, {"iid": "n3_s03182_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0, 2], [1, 2]]}, "draw_seed": 338470901, "tag": "n3"}, {"iid": "n3_s03206_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [], [1, 2]]}, "draw_seed": 340870901, "tag": "n3"}, {"iid": "n3_s03223_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [1], [0, 1, 2]]}, "draw_seed": 342570901, "tag": "n3"}, {"iid": "n3_s03248_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [1, 2], []]}, "draw_seed": 345070901, "tag": "n3"}, {"iid": "n3_s03271_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [], [0, 1, 2]]}, "draw_seed": 347370901, "tag": "n3"}, {"iid": "n3_s03293_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0, 1], [0, 2]]}, "draw_seed": 349570901, "tag": "n3"}, {"iid": "n3_s03314_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [1, 2], [1]]}, "draw_seed": 351670901, "tag": "n3"}, {"iid": "n3_s03338_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0], [1]]}, "draw_seed": 354070901, "tag": "n3"}, {"iid": "n3_s03361_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [2], [0]]}, "draw_seed": 356370901, "tag": "n3"}, {"iid": "n3_s03376_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [1, 2], []]}, "draw_seed": 357870901, "tag": "n3"}, {"iid": "n3_s03400_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0], []]}, "draw_seed": 360270901, "tag": "n3"}, {"iid": "n3_s03427_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [2], [0, 1]]}, "draw_seed": 362970901, "tag": "n3"}, {"iid": "n3_s03440_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [1, 2], []]}, "draw_seed": 364270901, "tag": "n3"}, {"iid": "n3_s03453_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1, 2], [0, 2]]}, "draw_seed": 365570901, "tag": "n3"}, {"iid": "n3_s03486_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1], [1, 2]]}, "draw_seed": 368870901, "tag": "n3"}, {"iid": "n3_s03498_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 2], [1]]}, "draw_seed": 370070901, "tag": "n3"}, {"iid": "n3_s03520_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [], []]}, "draw_seed": 372270901, "tag": "n3"}, {"iid": "n3_s03536_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1], []]}, "draw_seed": 373870901, "tag": "n3"}, {"iid": "n3_s03555_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [2], [0, 1]]}, "draw_seed": 375770901, "tag": "n3"}, {"iid": "n3_s03579_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0, 1, 2], [0, 1]]}, "draw_seed": 378170901, "tag": "n3"}, {"iid": "n3_s03603_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [1], [0, 1]]}, "draw_seed": 380570901, "tag": "n3"}, {"iid": "n3_s03634_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [1, 2], [1]]}, "draw_seed": 383670901, "tag": "n3"}, {"iid": "n3_s03661_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0], [0, 2]]}, "draw_seed": 386370901, "tag": "n3"}, {"iid": "n3_s03679_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1], [0, 1, 2]]}, "draw_seed": 388170901, "tag": "n3"}, {"iid": "n3_s03710_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1, 2], [1, 2]]}, "draw_seed": 391270901, "tag": "n3"}, {"iid": "n3_s03731_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1], [0, 1]]}, "draw_seed": 393370901, "tag": "n3"}, {"iid": "n3_s03756_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 2], [2]]}, "draw_seed": 395870901, "tag": "n3"}, {"iid": "n3_s03771_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1, 2], [0, 1]]}, "draw_seed": 397370901, "tag": "n3"}, {"iid": "n3_s03797_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [1], [0, 2]]}, "draw_seed": 399970901, "tag": "n3"}, {"iid": "n3_s03821_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 2], [0, 2]]}, "draw_seed": 402370901, "tag": "n3"}, {"iid": "n3_s03838_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], [1, 2]]}, "draw_seed": 404070901, "tag": "n3"}, {"iid": "n3_s03855_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0], [0, 1, 2]]}, "draw_seed": 405770901, "tag": "n3"}, {"iid": "n3_s03876_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [2], [2]]}, "draw_seed": 407870901, "tag": "n3"}, {"iid": "n3_s03903_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 410570901, "tag": "n3"}, {"iid": "n3_s03921_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1], [0]]}, "draw_seed": 412370901, "tag": "n3"}, {"iid": "n3_s03935_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1], [0, 1, 2]]}, "draw_seed": 413770901, "tag": "n3"}, {"iid": "n3_s03955_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1, 2], [0, 1]]}, "draw_seed": 415770901, "tag": "n3"}, {"iid": "n3_s03979_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0], [0, 1]]}, "draw_seed": 418170901, "tag": "n3"}, {"iid": "n3_s03993_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1], [0]]}, "draw_seed": 419570901, "tag": "n3"}, {"iid": "n3_s04017_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [0]]}, "draw_seed": 421970901, "tag": "n3"}, {"iid": "n3_s04031_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 423370901, "tag": "n3"}, {"iid": "n3_s04048_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1], []]}, "draw_seed": 425070901, "tag": "n3"}, {"iid": "n3_s04066_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [2], [1]]}, "draw_seed": 426870901, "tag": "n3"}, {"iid": "n3_s04095_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 429770901, "tag": "n3"}, {"iid": "named_mar_textbook_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [0]]}, "draw_seed": 20286456, "tag": "named"}, {"iid": "named_mnar_on_partial_cause_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [0]]}, "draw_seed": 20309786, "tag": "named"}, {"iid": "named_self_censor_v1_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[0], []]}, "draw_seed": 20325342, "tag": "named"}, {"iid": "named_three_var_mixed_d1", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0], [2]]}, "draw_seed": 20348672, "tag": "named"}, {"iid": "n4_r0006_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1]}, "r_parents": [[2, 3], [2], [0, 3], [0, 1, 3]]}, "draw_seed": 25271087, "tag": "n4"}, {"iid": "n4_r0014_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[3], [1], [0, 2], [0, 2, 3]]}, "draw_seed": 25271335, "tag": "n4"}, {"iid": "n4_r0022_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0, 2]}, "r_parents": [[0], [0, 2], [0, 3], [0, 1, 3]]}, "draw_seed": 25271583, "tag": "n4"}, {"iid": "n4_r0030_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": []}, "r_parents": [[0, 2, 3], [3], [0], [3]]}, "draw_seed": 25271831, "tag": "n4"}, {"iid": "n4_r0038_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0]}, "r_parents": [[0, 3], [1, 3], [0, 2], [2]]}, "draw_seed": 25272079, "tag": "n4"}, {"iid": "n4_r0046_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": []}, "r_parents": [[1], [0, 2, 3], [2], [0, 2]]}, "draw_seed": 25272327, "tag": "n4"}, {"iid": "n4_r0054_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 1]}, "r_parents": [[0], [1, 2, 3], [3], [0, 1, 3]]}, "draw_seed": 25272575, "tag": "n4"}, {"iid": "n4_r0062_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": []}, "r_parents": [[0, 2, 3], [0, 1, 2, 3], [2], [0, 2]]}, "draw_seed": 25272823, "tag": "n4"}, {"iid": "n4_r0070_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": []}, "r_parents": [[0, 3], [3], [], [1]]}, "draw_seed": 25273071, "tag": "n4"}, {"iid": "n4_r0078_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [2]}, "r_parents": [[1, 2, 3], [3], [2], [0]]}, "draw_seed": 25273319, "tag": "n4"}, {"iid": "n4_r0086_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0]}, "r_parents": [[1], [1, 2, 3], [0, 1, 2, 3], [0, 1]]}, "draw_seed": 25273567, "tag": "n4"}, {"iid": "n4_r0094_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1]}, "r_parents": [[1, 3], [1], [0, 1, 3], [0, 1]]}, "draw_seed": 25273815, "tag": "n4"}, {"iid": "n4_r0102_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [1]}, "r_parents": [[], [0, 1, 2, 3], [1, 3], [0, 1, 2, 3]]}, "draw_seed": 25274063, "tag": "n4"}, {"iid": "n4_r0110_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [1]}, "r_parents": [[0], [2, 3], [1, 2], []]}, "draw_seed": 25274311, "tag": "n4"}, {"iid": "n4_r0118_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0]}, "r_parents": [[], [0, 2, 3], [1, 2], [2]]}, "draw_seed": 25274559, "tag": "n4"}, {"iid": "n4_r0126_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1, 2]}, "r_parents": [[], [1, 2], [2], []]}, "draw_seed": 25274807, "tag": "n4"}, {"iid": "n4_r0134_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [1, 2]}, "r_parents": [[0, 2, 3], [0, 1], [0, 2], [0]]}, "draw_seed": 25275055, "tag": "n4"}, {"iid": "n4_r0142_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": []}, "r_parents": [[2, 3], [1], [0], [0, 1, 2]]}, "draw_seed": 25275303, "tag": "n4"}, {"iid": "n4_r0150_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [1]}, "r_parents": [[0, 3], [0, 1, 2, 3], [0], [0, 2]]}, "draw_seed": 25275551, "tag": "n4"}, {"iid": "n4_r0158_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": []}, "r_parents": [[0, 1, 2], [], [0, 2, 3], [0, 1, 2]]}, "draw_seed": 25275799, "tag": "n4"}, {"iid": "n4_r0166_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": []}, "r_parents": [[0, 1, 2], [1], [0, 2], [0, 1, 2, 3]]}, "draw_seed": 25276047, "tag": "n4"}, {"iid": "n4_r0174_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1]}, "r_parents": [[0, 1, 3], [1, 2, 3], [0, 1, 2, 3], [1, 3]]}, "draw_seed": 25276295, "tag": "n4"}, {"iid": "n4_r0182_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [1, 2]}, "r_parents": [[0, 1, 2], [3], [0, 1, 3], [3]]}, "draw_seed": 25276543, "tag": "n4"}, {"iid": "n4_r0190_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [1]}, "r_parents": [[0, 1, 3], [0, 1], [1, 2], [0]]}, "draw_seed": 25276791, "tag": "n4"}, {"iid": "n4_r0198_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [1, 2]}, "r_parents": [[1, 2, 3], [1, 2, 3], [1, 2, 3], [0, 1, 3]]}, "draw_seed": 25277039, "tag": "n4"}]''')
SHARD_IDX = 2
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
