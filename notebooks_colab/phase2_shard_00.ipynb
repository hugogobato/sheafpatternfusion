# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 00/8
# Jobs: 197. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00191_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 39370901, "tag": "n3"}, {"iid": "n3_s00228_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [2], [2]]}, "draw_seed": 43070901, "tag": "n3"}, {"iid": "n3_s00258_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [], [1]]}, "draw_seed": 46070901, "tag": "n3"}, {"iid": "n3_s00282_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1], [1]]}, "draw_seed": 48470901, "tag": "n3"}, {"iid": "n3_s00299_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 2], [0, 1]]}, "draw_seed": 50170901, "tag": "n3"}, {"iid": "n3_s00328_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0], []]}, "draw_seed": 53070901, "tag": "n3"}, {"iid": "n3_s00344_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0, 1], []]}, "draw_seed": 54670901, "tag": "n3"}, {"iid": "n3_s00374_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [1, 2], [1, 2]]}, "draw_seed": 57670901, "tag": "n3"}, {"iid": "n3_s00400_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [
d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [], [0, 2]]}, "draw_seed": 359970901, "tag": "n3"}, {"iid": "n3_s03417_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1], [0]]}, "draw_seed": 361970901, "tag": "n3"}, {"iid": "n3_s03437_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 2], [0, 2]]}, "draw_seed": 363970901, "tag": "n3"}, {"iid": "n3_s03451_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1, 2], [0, 1]]}, "draw_seed": 365370901, "tag": "n3"}, {"iid": "n3_s03478_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [1], [1, 2]]}, "draw_seed": 368070901, "tag": "n3"}, {"iid": "n3_s03496_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 2], []]}, "draw_seed": 369870901, "tag": "n3"}, {"iid": "n3_s03518_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1, 2], [1, 2]]}, "draw_seed": 372070901, "tag": "n3"}, {"iid": "n3_s03530_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0], [1]]}, "draw_seed": 373270901, "tag": "n3"}, {"iid": "n3_s03546_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0, 1], [1]]}, "draw_seed": 374870901, "tag": "n3"}, {"iid": "n3_s03572_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1, 2], [2]]}, "draw_seed": 377470901, "tag": "n3"}, {"iid": "n3_s03597_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0], [0, 2]]}, "draw_seed": 379970901, "tag": "n3"}, {"iid": "n3_s03630_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 2], [1, 2]]}, "draw_seed": 383270901, "tag": "n3"}, {"iid": "n3_s03649_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [], [0]]}, "draw_seed": 385170901, "tag": "n3"}, {"iid": "n3_s03676_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1], [2]]}, "draw_seed": 387870901, "tag": "n3"}, {"iid": "n3_s03700_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [1, 2], [2]]}, "draw_seed": 390270901, "tag": "n3"}, {"iid": "n3_s03725_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0], [0, 2]]}, "draw_seed": 392770901, "tag": "n3"}, {"iid": "n3_s03750_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [2], [1, 2]]}, "draw_seed": 395270901, "tag": "n3"}, {"iid": "n3_s03768_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1, 2], []]}, "draw_seed": 397070901, "tag": "n3"}, {"iid": "n3_s03789_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0], [0, 2]]}, "draw_seed": 399170901, "tag": "n3"}, {"iid": "n3_s03816_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 2], []]}, "draw_seed": 401870901, "tag": "n3"}, {"iid": "n3_s03834_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], [1]]}, "draw_seed": 403670901, "tag": "n3"}, {"iid": "n3_s03850_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0], [1]]}, "draw_seed": 405270901, "tag": "n3"}, {"iid": "n3_s03874_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [2], [1]]}, "draw_seed": 407670901, "tag": "n3"}, {"iid": "n3_s03901_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1, 2], [0, 2]]}, "draw_seed": 410370901, "tag": "n3"}, {"iid": "n3_s03915_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0], [0, 1]]}, "draw_seed": 411770901, "tag": "n3"}, {"iid": "n3_s03932_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1], [2]]}, "draw_seed": 413470901, "tag": "n3"}, {"iid": "n3_s03952_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1, 2], []]}, "draw_seed": 415470901, "tag": "n3"}, {"iid": "n3_s03971_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [], [0, 1]]}, "draw_seed": 417370901, "tag": "n3"}, {"iid": "n3_s03989_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1], [0, 2]]}, "draw_seed": 419170901, "tag": "n3"}, {"iid": "n3_s04009_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 2], [0]]}, "draw_seed": 421170901, "tag": "n3"}, {"iid": "n3_s04028_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1, 2], [2]]}, "draw_seed": 423070901, "tag": "n3"}, {"iid": "n3_s04041_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0], [0]]}, "draw_seed": 424370901, "tag": "n3"}, {"iid": "n3_s04058_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 1], [1]]}, "draw_seed": 426070901, "tag": "n3"}, {"iid": "n3_s04080_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1, 2], []]}, "draw_seed": 428270901, "tag": "n3"}, {"iid": "named_double_self_censor_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[0], [1]]}, "draw_seed": 20278680, "tag": "named"}, {"iid": "named_mediated_mnar_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[1], [0, 1]]}, "draw_seed": 20302010, "tag": "named"}, {"iid": "named_self_censor_v1_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[0], []]}, "draw_seed": 20325340, "tag": "named"}, {"iid": "named_three_var_double_self_d2", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1], [2]]}, "draw_seed": 20340896, "tag": "named"}, {"iid": "n4_r0004_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [2]}, "r_parents": [[1, 2], [1], [1, 2, 3], [2]]}, "draw_seed": 25271025, "tag": "n4"}, {"iid": "n4_r0012_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [2]}, "r_parents": [[1], [0], [0, 2], [0, 1]]}, "draw_seed": 25271273, "tag": "n4"}, {"iid": "n4_r0020_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [1, 2]}, "r_parents": [[2], [1, 2], [2, 3], [0, 1, 3]]}, "draw_seed": 25271521, "tag": "n4"}, {"iid": "n4_r0028_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0]}, "r_parents": [[1, 2, 3], [2, 3], [0, 2, 3], [1, 2]]}, "draw_seed": 25271769, "tag": "n4"}, {"iid": "n4_r0036_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [2]}, "r_parents": [[0, 1, 2, 3], [0, 3], [0, 3], [0, 2, 3]]}, "draw_seed": 25272017, "tag": "n4"}, {"iid": "n4_r0044_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0]}, "r_parents": [[0, 1, 2, 3], [0], [0, 1, 2], [1]]}, "draw_seed": 25272265, "tag": "n4"}, {"iid": "n4_r0052_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0]}, "r_parents": [[1, 2], [0, 2, 3], [1], [1, 3]]}, "draw_seed": 25272513, "tag": "n4"}, {"iid": "n4_r0060_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1]}, "r_parents": [[0, 2, 3], [1], [0, 1, 2, 3], [0, 3]]}, "draw_seed": 25272761, "tag": "n4"}, {"iid": "n4_r0068_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1, 2]}, "r_parents": [[0, 1, 2, 3], [1], [0, 1, 3], [1, 3]]}, "draw_seed": 25273009, "tag": "n4"}, {"iid": "n4_r0076_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [1, 2]}, "r_parents": [[0, 1], [0, 1, 2, 3], [0], [1, 2, 3]]}, "draw_seed": 25273257, "tag": "n4"}, {"iid": "n4_r0084_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [2]}, "r_parents": [[1, 2], [0, 2], [0, 1, 3], [0]]}, "draw_seed": 25273505, "tag": "n4"}, {"iid": "n4_r0092_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0]}, "r_parents": [[0, 1], [2, 3], [0, 1, 3], [0]]}, "draw_seed": 25273753, "tag": "n4"}, {"iid": "n4_r0100_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [2]}, "r_parents": [[2], [0], [3], [0]]}, "draw_seed": 25274001, "tag": "n4"}, {"iid": "n4_r0108_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1]}, "r_parents": [[0, 1, 2, 3], [], [2], [0, 2, 3]]}, "draw_seed": 25274249, "tag": "n4"}, {"iid": "n4_r0116_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": []}, "r_parents": [[1, 2, 3], [1, 2], [0, 1, 2], [0, 1]]}, "draw_seed": 25274497, "tag": "n4"}, {"iid": "n4_r0124_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [1, 2]}, "r_parents": [[0, 2], [2], [1, 2, 3], [1, 3]]}, "draw_seed": 25274745, "tag": "n4"}, {"iid": "n4_r0132_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 2]}, "r_parents": [[0, 2], [0, 1, 2], [0, 3], [0, 2, 3]]}, "draw_seed": 25274993, "tag": "n4"}, {"iid": "n4_r0140_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1, 2]}, "r_parents": [[1, 2, 3], [0, 1, 2, 3], [1, 3], [1, 3]]}, "draw_seed": 25275241, "tag": "n4"}, {"iid": "n4_r0148_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 1]}, "r_parents": [[], [0, 2, 3], [], [0, 3]]}, "draw_seed": 25275489, "tag": "n4"}, {"iid": "n4_r0156_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [2]}, "r_parents": [[2], [2], [0, 1, 2], [0, 2]]}, "draw_seed": 25275737, "tag": "n4"}, {"iid": "n4_r0164_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 2]}, "r_parents": [[0, 2, 3], [1, 2], [0, 1, 3], []]}, "draw_seed": 25275985, "tag": "n4"}, {"iid": "n4_r0172_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [1, 2]}, "r_parents": [[0, 1, 2, 3], [1, 2], [1, 2], [2]]}, "draw_seed": 25276233, "tag": "n4"}, {"iid": "n4_r0180_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1, 2]}, "r_parents": [[2, 3], [0, 3], [0, 1, 3], [0, 1, 3]]}, "draw_seed": 25276481, "tag": "n4"}, {"iid": "n4_r0188_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [2]}, "r_parents": [[1, 2], [1], [3], [0, 2, 3]]}, "draw_seed": 25276729, "tag": "n4"}, {"iid": "n4_r0196_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 2]}, "r_parents": [[0, 1, 2], [1, 2], [0, 2], [0, 1, 2, 3]]}, "draw_seed": 25276977, "tag": "n4"}]''')
SHARD_IDX = 0
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
