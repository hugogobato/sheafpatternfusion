# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 05/8
# Jobs: 196. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00216_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 1], []]}, "draw_seed": 41870901, "tag": "n3"}, {"iid": "n3_s00255_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 45770901, "tag": "n3"}, {"iid": "n3_s00274_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [1], [1]]}, "draw_seed": 47670901, "tag": "n3"}, {"iid": "n3_s00291_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [2], [0, 1]]}, "draw_seed": 49370901, "tag": "n3"}, {"iid": "n3_s00312_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1, 2], []]}, "draw_seed": 51470901, "tag": "n3"}, {"iid": "n3_s00339_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [1], [0, 1]]}, "draw_seed": 54170901, "tag": "n3"}, {"iid": "n3_s00358_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [2], [1, 2]]}, "draw_seed": 56070901, "tag": "n3"}, {"iid": "n3_s00391_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [], [0, 1, 2]]}, "draw_seed": 59370901, "tag": "n3"}, {"iid": "n3_s00409_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [
d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [], [0]]}, "draw_seed": 359570901, "tag": "n3"}, {"iid": "n3_s03405_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0], [0, 2]]}, "draw_seed": 360770901, "tag": "n3"}, {"iid": "n3_s03432_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 2], []]}, "draw_seed": 363470901, "tag": "n3"}, {"iid": "n3_s03445_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [1, 2], [0, 2]]}, "draw_seed": 364770901, "tag": "n3"}, {"iid": "n3_s03467_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0], [0, 1]]}, "draw_seed": 366970901, "tag": "n3"}, {"iid": "n3_s03490_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [2], [1]]}, "draw_seed": 369270901, "tag": "n3"}, {"iid": "n3_s03514_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1, 2], [1]]}, "draw_seed": 371670901, "tag": "n3"}, {"iid": "n3_s03527_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [], [0, 1, 2]]}, "draw_seed": 372970901, "tag": "n3"}, {"iid": "n3_s03541_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1], [0, 2]]}, "draw_seed": 374370901, "tag": "n3"}, {"iid": "n3_s03565_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 2]]}, "draw_seed": 376770901, "tag": "n3"}, {"iid": "n3_s03588_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [], [2]]}, "draw_seed": 379070901, "tag": "n3"}, {"iid": "n3_s03611_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1], [0, 1]]}, "draw_seed": 381370901, "tag": "n3"}, {"iid": "n3_s03643_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1, 2], [0, 1]]}, "draw_seed": 384570901, "tag": "n3"}, {"iid": "n3_s03671_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [1], [0, 1, 2]]}, "draw_seed": 387370901, "tag": "n3"}, {"iid": "n3_s03688_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 2], []]}, "draw_seed": 389070901, "tag": "n3"}, {"iid": "n3_s03720_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0], []]}, "draw_seed": 392270901, "tag": "n3"}, {"iid": "n3_s03734_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1], [1, 2]]}, "draw_seed": 393670901, "tag": "n3"}, {"iid": "n3_s03761_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1, 2], [0]]}, "draw_seed": 396370901, "tag": "n3"}, {"iid": "n3_s03777_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [], [0]]}, "draw_seed": 397970901, "tag": "n3"}, {"iid": "n3_s03811_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [2], [0, 1]]}, "draw_seed": 401370901, "tag": "n3"}, {"iid": "n3_s03824_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [1, 2], []]}, "draw_seed": 402670901, "tag": "n3"}, {"iid": "n3_s03846_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [], [1, 2]]}, "draw_seed": 404870901, "tag": "n3"}, {"iid": "n3_s03867_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1], [0, 1]]}, "draw_seed": 406970901, "tag": "n3"}, {"iid": "n3_s03890_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [1, 2], [1]]}, "draw_seed": 409270901, "tag": "n3"}, {"iid": "n3_s03911_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [], [0, 1, 2]]}, "draw_seed": 411370901, "tag": "n3"}, {"iid": "n3_s03924_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1], [2]]}, "draw_seed": 412670901, "tag": "n3"}, {"iid": "n3_s03943_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [2], [0, 1, 2]]}, "draw_seed": 414570901, "tag": "n3"}, {"iid": "n3_s03962_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1, 2], [1]]}, "draw_seed": 416470901, "tag": "n3"}, {"iid": "n3_s03985_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1], [0]]}, "draw_seed": 418770901, "tag": "n3"}, {"iid": "n3_s04003_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [2], [0, 1]]}, "draw_seed": 420570901, "tag": "n3"}, {"iid": "n3_s04022_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [1, 2]]}, "draw_seed": 422470901, "tag": "n3"}, {"iid": "n3_s04034_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [], [1]]}, "draw_seed": 423670901, "tag": "n3"}, {"iid": "n3_s04054_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1], [1, 2]]}, "draw_seed": 425670901, "tag": "n3"}, {"iid": "n3_s04077_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 2]]}, "draw_seed": 427970901, "tag": "n3"}, {"iid": "named_collider_selection_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[], [0, 1]]}, "draw_seed": 20270903, "tag": "named"}, {"iid": "named_mcar_reference_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], []]}, "draw_seed": 20294233, "tag": "named"}, {"iid": "named_mutual_selection_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[], [1], [0]]}, "draw_seed": 20317563, "tag": "named"}, {"iid": "named_self_censor_v2_chain_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [1]]}, "draw_seed": 20333119, "tag": "named"}, {"iid": "n4_r0001_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": []}, "r_parents": [[0, 1, 2], [1, 2, 3], [1, 2], [1, 2]]}, "draw_seed": 25270932, "tag": "n4"}, {"iid": "n4_r0009_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1, 2]}, "r_parents": [[1, 2, 3], [0, 1], [1, 2], [0, 3]]}, "draw_seed": 25271180, "tag": "n4"}, {"iid": "n4_r0017_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [2]}, "r_parents": [[], [0, 1, 2, 3], [1], [2, 3]]}, "draw_seed": 25271428, "tag": "n4"}, {"iid": "n4_r0025_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": []}, "r_parents": [[0, 1, 2], [1, 2], [1, 2, 3], [0, 2]]}, "draw_seed": 25271676, "tag": "n4"}, {"iid": "n4_r0033_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1]}, "r_parents": [[1, 2, 3], [0, 1, 3], [0, 3], [2]]}, "draw_seed": 25271924, "tag": "n4"}, {"iid": "n4_r0041_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1]}, "r_parents": [[2], [1, 3], [0], [0, 1, 2, 3]]}, "draw_seed": 25272172, "tag": "n4"}, {"iid": "n4_r0049_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": []}, "r_parents": [[0], [1, 2], [0, 1, 3], [0, 1, 2]]}, "draw_seed": 25272420, "tag": "n4"}, {"iid": "n4_r0057_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 2]}, "r_parents": [[1], [0, 2], [2], [0, 1]]}, "draw_seed": 25272668, "tag": "n4"}, {"iid": "n4_r0065_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": []}, "r_parents": [[], [0, 1, 2, 3], [3], [0, 1]]}, "draw_seed": 25272916, "tag": "n4"}, {"iid": "n4_r0073_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": []}, "r_parents": [[0, 1, 2, 3], [0, 1], [2, 3], [2, 3]]}, "draw_seed": 25273164, "tag": "n4"}, {"iid": "n4_r0081_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [2]}, "r_parents": [[0, 3], [2], [2, 3], [2]]}, "draw_seed": 25273412, "tag": "n4"}, {"iid": "n4_r0089_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 1, 2]}, "r_parents": [[0, 1, 3], [], [2, 3], [0, 3]]}, "draw_seed": 25273660, "tag": "n4"}, {"iid": "n4_r0097_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1, 2]}, "r_parents": [[1, 3], [0, 1], [1, 3], [0, 2, 3]]}, "draw_seed": 25273908, "tag": "n4"}, {"iid": "n4_r0105_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 2]}, "r_parents": [[0, 1], [1, 3], [0, 1, 2, 3], [0, 2, 3]]}, "draw_seed": 25274156, "tag": "n4"}, {"iid": "n4_r0113_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [1, 2]}, "r_parents": [[0, 1, 3], [0, 2, 3], [1, 2, 3], [2]]}, "draw_seed": 25274404, "tag": "n4"}, {"iid": "n4_r0121_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1, 2]}, "r_parents": [[1, 3], [2], [2, 3], [0, 1]]}, "draw_seed": 25274652, "tag": "n4"}, {"iid": "n4_r0129_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0]}, "r_parents": [[0, 3], [1], [0, 1], [0, 1, 2]]}, "draw_seed": 25274900, "tag": "n4"}, {"iid": "n4_r0137_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [1, 2]}, "r_parents": [[0, 1, 2, 3], [1, 2], [0, 3], [3]]}, "draw_seed": 25275148, "tag": "n4"}, {"iid": "n4_r0145_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [1]}, "r_parents": [[2, 3], [0], [0, 2], [0, 1]]}, "draw_seed": 25275396, "tag": "n4"}, {"iid": "n4_r0153_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 2]}, "r_parents": [[0], [0, 1, 3], [1, 2], [0, 1]]}, "draw_seed": 25275644, "tag": "n4"}, {"iid": "n4_r0161_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1]}, "r_parents": [[0, 1, 3], [1, 3], [1, 2, 3], [0, 2]]}, "draw_seed": 25275892, "tag": "n4"}, {"iid": "n4_r0169_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [2]}, "r_parents": [[0, 1], [0, 1], [0, 1], [2]]}, "draw_seed": 25276140, "tag": "n4"}, {"iid": "n4_r0177_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [2]}, "r_parents": [[3], [2, 3], [0, 1], [0, 3]]}, "draw_seed": 25276388, "tag": "n4"}, {"iid": "n4_r0185_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 1, 2]}, "r_parents": [[0, 1], [2, 3], [], [0, 2, 3]]}, "draw_seed": 25276636, "tag": "n4"}, {"iid": "n4_r0193_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [2]}, "r_parents": [[0, 1, 3], [], [0, 2], [1, 2]]}, "draw_seed": 25276884, "tag": "n4"}]''')
SHARD_IDX = 5
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
