# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 06/8
# Jobs: 196. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
import pathlib
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00219_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 1], [0, 1]]}, "draw_seed": 42170901, "tag": "n3"}, {"iid": "n3_s00256_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [], []]}, "draw_seed": 45870901, "tag": "n3"}, {"iid": "n3_s00278_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [1], [1, 2]]}, "draw_seed": 48070901, "tag": "n3"}, {"iid": "n3_s00292_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [2], [2]]}, "draw_seed": 49470901, "tag": "n3"}, {"iid": "n3_s00319_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 52170901, "tag": "n3"}, {"iid": "n3_s00342_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [1], [1, 2]]}, "draw_seed": 54470901, "tag": "n3"}, {"iid": "n3_s00366_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0, 2], [1, 2]]}, "draw_seed": 56870901, "tag": "n3"}, {"iid": "n3_s00393_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [0], [0]]}, "draw_seed": 59570901, "tag": "n3"}, {"iid": "n3_s00412_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [
d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 2], [1]]}, "draw_seed": 357270901, "tag": "n3"}, {"iid": "n3_s03394_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [], [1]]}, "draw_seed": 359670901, "tag": "n3"}, {"iid": "n3_s03409_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [1], [0]]}, "draw_seed": 361170901, "tag": "n3"}, {"iid": "n3_s03433_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 2], [0]]}, "draw_seed": 363570901, "tag": "n3"}, {"iid": "n3_s03448_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1, 2], []]}, "draw_seed": 365070901, "tag": "n3"}, {"iid": "n3_s03468_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0], [2]]}, "draw_seed": 367070901, "tag": "n3"}, {"iid": "n3_s03491_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [2], [0, 1]]}, "draw_seed": 369370901, "tag": "n3"}, {"iid": "n3_s03515_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1, 2], [0, 1]]}, "draw_seed": 371770901, "tag": "n3"}, {"iid": "n3_s03528_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0], []]}, "draw_seed": 373070901, "tag": "n3"}, {"iid": "n3_s03542_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1], [1, 2]]}, "draw_seed": 374470901, "tag": "n3"}, {"iid": "n3_s03569_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1, 2], [0]]}, "draw_seed": 377170901, "tag": "n3"}, {"iid": "n3_s03590_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [], [1, 2]]}, "draw_seed": 379270901, "tag": "n3"}, {"iid": "n3_s03612_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1], [2]]}, "draw_seed": 381470901, "tag": "n3"}, {"iid": "n3_s03644_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1, 2], [2]]}, "draw_seed": 384670901, "tag": "n3"}, {"iid": "n3_s03673_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1], [0]]}, "draw_seed": 387570901, "tag": "n3"}, {"iid": "n3_s03689_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 2], [0]]}, "draw_seed": 389170901, "tag": "n3"}, {"iid": "n3_s03721_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0], [0]]}, "draw_seed": 392370901, "tag": "n3"}, {"iid": "n3_s03736_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1], []]}, "draw_seed": 393870901, "tag": "n3"}, {"iid": "n3_s03763_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1, 2], [0, 1]]}, "draw_seed": 396570901, "tag": "n3"}, {"iid": "n3_s03779_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [], [0, 1]]}, "draw_seed": 398170901, "tag": "n3"}, {"iid": "n3_s03813_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [2], [0, 2]]}, "draw_seed": 401570901, "tag": "n3"}, {"iid": "n3_s03825_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [1, 2], [0]]}, "draw_seed": 402770901, "tag": "n3"}, {"iid": "n3_s03848_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0], []]}, "draw_seed": 405070901, "tag": "n3"}, {"iid": "n3_s03871_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1], [0, 1, 2]]}, "draw_seed": 407370901, "tag": "n3"}, {"iid": "n3_s03895_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [1, 2], [0, 1, 2]]}, "draw_seed": 409770901, "tag": "n3"}, {"iid": "n3_s03913_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0], [0]]}, "draw_seed": 411570901, "tag": "n3"}, {"iid": "n3_s03928_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1], []]}, "draw_seed": 413070901, "tag": "n3"}, {"iid": "n3_s03946_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 2], [1]]}, "draw_seed": 414870901, "tag": "n3"}, {"iid": "n3_s03968_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [], []]}, "draw_seed": 417070901, "tag": "n3"}, {"iid": "n3_s03987_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1], [0, 1]]}, "draw_seed": 418970901, "tag": "n3"}, {"iid": "n3_s04004_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [2], [2]]}, "draw_seed": 420670901, "tag": "n3"}, {"iid": "n3_s04023_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [0, 1, 2]]}, "draw_seed": 422570901, "tag": "n3"}, {"iid": "n3_s04036_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [], [2]]}, "draw_seed": 423870901, "tag": "n3"}, {"iid": "n3_s04055_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1], [0, 1, 2]]}, "draw_seed": 425770901, "tag": "n3"}, {"iid": "n3_s04078_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 2], [1, 2]]}, "draw_seed": 428070901, "tag": "n3"}, {"iid": "named_double_self_censor_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[0], [1]]}, "draw_seed": 20278678, "tag": "named"}, {"iid": "named_mcar_reference_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], []]}, "draw_seed": 20294234, "tag": "named"}, {"iid": "named_mutual_selection_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[], [1], [0]]}, "draw_seed": 20317564, "tag": "named"}, {"iid": "named_three_var_double_self_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1], [2]]}, "draw_seed": 20340894, "tag": "named"}, {"iid": "n4_r0002_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": []}, "r_parents": [[0, 3], [3], [0, 3], [2]]}, "draw_seed": 25270963, "tag": "n4"}, {"iid": "n4_r0010_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [1]}, "r_parents": [[0, 2], [], [0, 2], [0, 3]]}, "draw_seed": 25271211, "tag": "n4"}, {"iid": "n4_r0018_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 2]}, "r_parents": [[2, 3], [0, 1, 2], [3], [0, 1, 2]]}, "draw_seed": 25271459, "tag": "n4"}, {"iid": "n4_r0026_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0]}, "r_parents": [[0, 1, 2], [2, 3], [2], [0, 2, 3]]}, "draw_seed": 25271707, "tag": "n4"}, {"iid": "n4_r0034_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 1]}, "r_parents": [[0, 1, 3], [0, 1, 2], [0], [0, 1, 2]]}, "draw_seed": 25271955, "tag": "n4"}, {"iid": "n4_r0042_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1]}, "r_parents": [[3], [2], [3], [1, 3]]}, "draw_seed": 25272203, "tag": "n4"}, {"iid": "n4_r0050_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1]}, "r_parents": [[1, 2, 3], [0, 1], [0], [0, 2]]}, "draw_seed": 25272451, "tag": "n4"}, {"iid": "n4_r0058_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1]}, "r_parents": [[], [0, 1, 2, 3], [0, 3], [3]]}, "draw_seed": 25272699, "tag": "n4"}, {"iid": "n4_r0066_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0]}, "r_parents": [[1], [1], [0, 1, 3], [0, 2, 3]]}, "draw_seed": 25272947, "tag": "n4"}, {"iid": "n4_r0074_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 2]}, "r_parents": [[1, 2, 3], [0, 2, 3], [3], [0, 1, 2, 3]]}, "draw_seed": 25273195, "tag": "n4"}, {"iid": "n4_r0082_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0]}, "r_parents": [[1, 2], [1, 2, 3], [3], [0, 2, 3]]}, "draw_seed": 25273443, "tag": "n4"}, {"iid": "n4_r0090_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1]}, "r_parents": [[0, 1], [0, 1], [1, 3], [2, 3]]}, "draw_seed": 25273691, "tag": "n4"}, {"iid": "n4_r0098_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [2]}, "r_parents": [[0, 2, 3], [], [1], [0, 1, 3]]}, "draw_seed": 25273939, "tag": "n4"}, {"iid": "n4_r0106_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[1, 3], [0, 2, 3], [2, 3], [0, 2]]}, "draw_seed": 25274187, "tag": "n4"}, {"iid": "n4_r0114_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1]}, "r_parents": [[0, 3], [2], [3], [1]]}, "draw_seed": 25274435, "tag": "n4"}, {"iid": "n4_r0122_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": []}, "r_parents": [[0, 2], [0, 2], [0], [0, 1, 2, 3]]}, "draw_seed": 25274683, "tag": "n4"}, {"iid": "n4_r0130_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [1]}, "r_parents": [[0, 1], [0, 2], [3], [0, 2, 3]]}, "draw_seed": 25274931, "tag": "n4"}, {"iid": "n4_r0138_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1, 2]}, "r_parents": [[2, 3], [1, 3], [2], [0, 1, 2, 3]]}, "draw_seed": 25275179, "tag": "n4"}, {"iid": "n4_r0146_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": []}, "r_parents": [[1, 2, 3], [0, 2, 3], [0, 1], [1, 2, 3]]}, "draw_seed": 25275427, "tag": "n4"}, {"iid": "n4_r0154_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [2]}, "r_parents": [[2, 3], [0, 3], [0, 1, 3], [0, 3]]}, "draw_seed": 25275675, "tag": "n4"}, {"iid": "n4_r0162_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1]}, "r_parents": [[0, 2], [3], [0, 2, 3], [0, 1]]}, "draw_seed": 25275923, "tag": "n4"}, {"iid": "n4_r0170_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1]}, "r_parents": [[0, 1, 3], [0, 3], [0, 1, 2, 3], [0, 1, 3]]}, "draw_seed": 25276171, "tag": "n4"}, {"iid": "n4_r0178_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [1, 2]}, "r_parents": [[1, 2, 3], [2], [3], [1]]}, "draw_seed": 25276419, "tag": "n4"}, {"iid": "n4_r0186_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [1]}, "r_parents": [[], [3], [3], [2, 3]]}, "draw_seed": 25276667, "tag": "n4"}, {"iid": "n4_r0194_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": []}, "r_parents": [[1, 2], [0, 1, 2], [2], [3]]}, "draw_seed": 25276915, "tag": "n4"}]''')
SHARD_IDX = 6
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
