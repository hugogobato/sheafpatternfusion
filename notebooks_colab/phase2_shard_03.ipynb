# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 03/8
# Jobs: 197. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
import pathlib
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00211_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [1], [0, 1]]}, "draw_seed": 41370901, "tag": "n3"}, {"iid": "n3_s00234_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 2], [1]]}, "draw_seed": 43670901, "tag": "n3"}, {"iid": "n3_s00266_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0], [1]]}, "draw_seed": 46870901, "tag": "n3"}, {"iid": "n3_s00286_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1], [1, 2]]}, "draw_seed": 48870901, "tag": "n3"}, {"iid": "n3_s00304_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [1, 2], []]}, "draw_seed": 50670901, "tag": "n3"}, {"iid": "n3_s00333_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0], [0, 2]]}, "draw_seed": 53570901, "tag": "n3"}, {"iid": "n3_s00351_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [
d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1], [0, 1]]}, "draw_seed": 323770901, "tag": "n3"}, {"iid": "n3_s03076_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [], [2]]}, "draw_seed": 327870901, "tag": "n3"}, {"iid": "n3_s03099_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0, 1], [0, 1]]}, "draw_seed": 330170901, "tag": "n3"}, {"iid": "n3_s03128_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0, 1, 2], []]}, "draw_seed": 333070901, "tag": "n3"}, {"iid": "n3_s03150_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0], [1, 2]]}, "draw_seed": 335270901, "tag": "n3"}, {"iid": "n3_s03162_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0, 1], [1]]}, "draw_seed": 336470901, "tag": "n3"}, {"iid": "n3_s03184_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1, 2], []]}, "draw_seed": 338670901, "tag": "n3"}, {"iid": "n3_s03207_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [], [0, 1, 2]]}, "draw_seed": 340970901, "tag": "n3"}, {"iid": "n3_s03225_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [0, 1], [0]]}, "draw_seed": 342770901, "tag": "n3"}, {"iid": "n3_s03251_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [1, 2], [0, 1]]}, "draw_seed": 345370901, "tag": "n3"}, {"iid": "n3_s03272_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0], []]}, "draw_seed": 347470901, "tag": "n3"}, {"iid": "n3_s03294_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0, 1], [1, 2]]}, "draw_seed": 349670901, "tag": "n3"}, {"iid": "n3_s03318_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [1, 2], [1, 2]]}, "draw_seed": 352070901, "tag": "n3"}, {"iid": "n3_s03340_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0], [2]]}, "draw_seed": 354270901, "tag": "n3"}, {"iid": "n3_s03363_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [2], [0, 1]]}, "draw_seed": 356570901, "tag": "n3"}, {"iid": "n3_s03388_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 1, 2], [2]]}, "draw_seed": 359070901, "tag": "n3"}, {"iid": "n3_s03401_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0], [0]]}, "draw_seed": 360370901, "tag": "n3"}, {"iid": "n3_s03428_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [2], [2]]}, "draw_seed": 363070901, "tag": "n3"}, {"iid": "n3_s03441_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [1, 2], [0]]}, "draw_seed": 364370901, "tag": "n3"}, {"iid": "n3_s03457_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [], [0]]}, "draw_seed": 365970901, "tag": "n3"}, {"iid": "n3_s03487_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1], [0, 1, 2]]}, "draw_seed": 368970901, "tag": "n3"}, {"iid": "n3_s03510_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [1, 2], [1, 2]]}, "draw_seed": 371270901, "tag": "n3"}, {"iid": "n3_s03524_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [], [2]]}, "draw_seed": 372670901, "tag": "n3"}, {"iid": "n3_s03537_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1], [0]]}, "draw_seed": 373970901, "tag": "n3"}, {"iid": "n3_s03556_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [2], [2]]}, "draw_seed": 375870901, "tag": "n3"}, {"iid": "n3_s03584_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [], []]}, "draw_seed": 378670901, "tag": "n3"}, {"iid": "n3_s03605_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [1], [0, 2]]}, "draw_seed": 380770901, "tag": "n3"}, {"iid": "n3_s03636_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [1, 2], [2]]}, "draw_seed": 383870901, "tag": "n3"}, {"iid": "n3_s03663_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0], [0, 1, 2]]}, "draw_seed": 386570901, "tag": "n3"}, {"iid": "n3_s03683_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [2], [0, 1]]}, "draw_seed": 388570901, "tag": "n3"}, {"iid": "n3_s03712_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [], []]}, "draw_seed": 391470901, "tag": "n3"}, {"iid": "n3_s03732_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1], [2]]}, "draw_seed": 393470901, "tag": "n3"}, {"iid": "n3_s03759_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 2], [0, 1, 2]]}, "draw_seed": 396170901, "tag": "n3"}, {"iid": "n3_s03773_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1, 2], [0, 2]]}, "draw_seed": 397570901, "tag": "n3"}, {"iid": "n3_s03798_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [1], [1, 2]]}, "draw_seed": 400070901, "tag": "n3"}, {"iid": "n3_s03822_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 2], [1, 2]]}, "draw_seed": 402470901, "tag": "n3"}, {"iid": "n3_s03839_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 404170901, "tag": "n3"}, {"iid": "n3_s03858_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [1], [1]]}, "draw_seed": 406070901, "tag": "n3"}, {"iid": "n3_s03886_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 2], [1, 2]]}, "draw_seed": 408870901, "tag": "n3"}, {"iid": "n3_s03906_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [], [1]]}, "draw_seed": 410870901, "tag": "n3"}, {"iid": "n3_s03922_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1], [1]]}, "draw_seed": 412470901, "tag": "n3"}, {"iid": "n3_s03936_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [2], []]}, "draw_seed": 413870901, "tag": "n3"}, {"iid": "n3_s03956_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1, 2], [2]]}, "draw_seed": 415870901, "tag": "n3"}, {"iid": "n3_s03983_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0], [0, 1, 2]]}, "draw_seed": 418570901, "tag": "n3"}, {"iid": "n3_s03994_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1], [1]]}, "draw_seed": 419670901, "tag": "n3"}, {"iid": "n3_s04020_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [2]]}, "draw_seed": 422270901, "tag": "n3"}, {"iid": "n3_s04032_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [], []]}, "draw_seed": 423470901, "tag": "n3"}, {"iid": "n3_s04052_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1], [2]]}, "draw_seed": 425470901, "tag": "n3"}, {"iid": "n3_s04070_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [2], [1, 2]]}, "draw_seed": 427270901, "tag": "n3"}, {"iid": "named_collider_selection_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[], [0, 1]]}, "draw_seed": 20270901, "tag": "named"}, {"iid": "named_mar_textbook_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [0]]}, "draw_seed": 20286457, "tag": "named"}, {"iid": "named_mnar_on_partial_cause_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [0]]}, "draw_seed": 20309787, "tag": "named"}, {"iid": "named_self_censor_v2_chain_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [1]]}, "draw_seed": 20333117, "tag": "named"}, {"iid": "named_three_var_mixed_d2", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0], [2]]}, "draw_seed": 20348673, "tag": "named"}, {"iid": "n4_r0007_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": []}, "r_parents": [[2, 3], [], [], [1, 2]]}, "draw_seed": 25271118, "tag": "n4"}, {"iid": "n4_r0015_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1]}, "r_parents": [[0, 1, 2, 3], [0], [], [0]]}, "draw_seed": 25271366, "tag": "n4"}, {"iid": "n4_r0023_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 2]}, "r_parents": [[0, 1, 2, 3], [0, 1, 3], [0, 1, 3], [0, 2]]}, "draw_seed": 25271614, "tag": "n4"}, {"iid": "n4_r0031_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[0, 2], [0, 2, 3], [0, 1, 2, 3], [0]]}, "draw_seed": 25271862, "tag": "n4"}, {"iid": "n4_r0039_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [2]}, "r_parents": [[0, 1, 2], [1, 2], [2], [3]]}, "draw_seed": 25272110, "tag": "n4"}, {"iid": "n4_r0047_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0]}, "r_parents": [[0, 1, 2, 3], [0, 2], [0], [2]]}, "draw_seed": 25272358, "tag": "n4"}, {"iid": "n4_r0055_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0, 1, 2]}, "r_parents": [[0, 3], [3], [1, 3], [0, 1, 2]]}, "draw_seed": 25272606, "tag": "n4"}, {"iid": "n4_r0063_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0]}, "r_parents": [[3], [0], [1, 3], [0, 2]]}, "draw_seed": 25272854, "tag": "n4"}, {"iid": "n4_r0071_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [1]}, "r_parents": [[2, 3], [1, 2, 3], [0, 3], [0, 2]]}, "draw_seed": 25273102, "tag": "n4"}, {"iid": "n4_r0079_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[3], [0, 1, 3], [0, 3], [0, 1]]}, "draw_seed": 25273350, "tag": "n4"}, {"iid": "n4_r0087_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 2]}, "r_parents": [[0, 1], [0, 1, 2], [2, 3], [0, 1, 2]]}, "draw_seed": 25273598, "tag": "n4"}, {"iid": "n4_r0095_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1, 2]}, "r_parents": [[0, 3], [1, 2, 3], [2], [0, 2]]}, "draw_seed": 25273846, "tag": "n4"}, {"iid": "n4_r0103_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1, 2]}, "r_parents": [[0, 1, 2], [2, 3], [1, 2, 3], [2, 3]]}, "draw_seed": 25274094, "tag": "n4"}, {"iid": "n4_r0111_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [2]}, "r_parents": [[2, 3], [0, 1, 3], [0, 1, 2], [1, 2]]}, "draw_seed": 25274342, "tag": "n4"}, {"iid": "n4_r0119_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[0], [0, 1, 2], [], [1, 3]]}, "draw_seed": 25274590, "tag": "n4"}, {"iid": "n4_r0127_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [2]}, "r_parents": [[0, 3], [0, 3], [1, 2, 3], [2, 3]]}, "draw_seed": 25274838, "tag": "n4"}, {"iid": "n4_r0135_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 2]}, "r_parents": [[0, 3], [1, 3], [0, 3], [0, 1, 3]]}, "draw_seed": 25275086, "tag": "n4"}, {"iid": "n4_r0143_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0, 1]}, "r_parents": [[0, 2], [0, 2], [0, 1, 3], [1]]}, "draw_seed": 25275334, "tag": "n4"}, {"iid": "n4_r0151_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 2]}, "r_parents": [[1, 2], [1, 3], [1, 2, 3], [0, 1, 2, 3]]}, "draw_seed": 25275582, "tag": "n4"}, {"iid": "n4_r0159_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [1, 2]}, "r_parents": [[], [0, 2], [1, 3], [3]]}, "draw_seed": 25275830, "tag": "n4"}, {"iid": "n4_r0167_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [2]}, "r_parents": [[2, 3], [2, 3], [1, 2], [0, 1, 2]]}, "draw_seed": 25276078, "tag": "n4"}, {"iid": "n4_r0175_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0]}, "r_parents": [[1, 2], [], [0, 1, 2, 3], [0, 2]]}, "draw_seed": 25276326, "tag": "n4"}, {"iid": "n4_r0183_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 2]}, "r_parents": [[2], [0, 2], [0, 1], [1]]}, "draw_seed": 25276574, "tag": "n4"}, {"iid": "n4_r0191_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1]}, "r_parents": [[], [0], [1, 2], [2, 3]]}, "draw_seed": 25276822, "tag": "n4"}, {"iid": "n4_r0199_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0]}, "r_parents": [[2], [0, 1, 2, 3], [1], [0]]}, "draw_seed": 25277070, "tag": "n4"}]''')
SHARD_IDX = 3
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
