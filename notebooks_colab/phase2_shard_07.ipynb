# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 07/8
# Jobs: 196. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00220_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 1], [2]]}, "draw_seed": 42270901, "tag": "n3"}, {"iid": "n3_s00257_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [], [0]]}, "draw_seed": 45970901, "tag": "n3"}, {"iid": "n3_s00280_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [0, 1], []]}, "draw_seed": 48270901, "tag": "n3"}, {"iid": "n3_s00294_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [2], [1, 2]]}, "draw_seed": 49670901, "tag": "n3"}, {"iid": "n3_s00326_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [], [1, 2]]}, "draw_seed": 52870901, "tag": "n3"}, {"iid": "n3_s00343_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [1], [0, 1, 2]]}, "draw_seed": 54570901, "tag": "n3"}, {"iid": "n3_s00373_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [1, 2], [0, 2]]}, "draw_seed": 57570901, "tag": "n3"}, {"iid": "n3_s00396_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [0], [2]]}, "draw_seed": 59870901, "tag": "n3"}, {"iid": "n3_s00413_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [
d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[], [1, 2], [1, 2]]}, "draw_seed": 281670901, "tag": "n3"}, {"iid": "n3_s02634_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [0], [1]]}, "draw_seed": 283670901, "tag": "n3"}, {"iid": "n3_s02672_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [1, 2], []]}, "draw_seed": 287470901, "tag": "n3"}, {"iid": "n3_s02707_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [1], [0, 1]]}, "draw_seed": 290970901, "tag": "n3"}, {"iid": "n3_s02726_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [2], [1, 2]]}, "draw_seed": 292870901, "tag": "n3"}, {"iid": "n3_s02750_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [0, 1, 2], [1, 2]]}, "draw_seed": 295270901, "tag": "n3"}, {"iid": "n3_s02774_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [1], [1, 2]]}, "draw_seed": 297670901, "tag": "n3"}, {"iid": "n3_s02791_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [2], [0, 1, 2]]}, "draw_seed": 299370901, "tag": "n3"}, {"iid": "n3_s02810_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0, 1, 2], [1]]}, "draw_seed": 301270901, "tag": "n3"}, {"iid": "n3_s02833_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [1], [0]]}, "draw_seed": 303570901, "tag": "n3"}, {"iid": "n3_s02866_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [1, 2], [1]]}, "draw_seed": 306870901, "tag": "n3"}, {"iid": "n3_s02882_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [], [1]]}, "draw_seed": 308470901, "tag": "n3"}, {"iid": "n3_s02896_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [1], []]}, "draw_seed": 309870901, "tag": "n3"}, {"iid": "n3_s02924_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [0, 2], [2]]}, "draw_seed": 312670901, "tag": "n3"}, {"iid": "n3_s02960_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [1], []]}, "draw_seed": 316270901, "tag": "n3"}, {"iid": "n3_s02980_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [2], [2]]}, "draw_seed": 318270901, "tag": "n3"}, {"iid": "n3_s03005_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [0, 1, 2], [0, 2]]}, "draw_seed": 320770901, "tag": "n3"}, {"iid": "n3_s03026_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [1], [1]]}, "draw_seed": 322870901, "tag": "n3"}, {"iid": "n3_s03061_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [1, 2], [0, 2]]}, "draw_seed": 326370901, "tag": "n3"}, {"iid": "n3_s03087_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0], [0, 1, 2]]}, "draw_seed": 328970901, "tag": "n3"}, {"iid": "n3_s03108_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [2], [2]]}, "draw_seed": 331070901, "tag": "n3"}, {"iid": "n3_s03140_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [], [2]]}, "draw_seed": 334270901, "tag": "n3"}, {"iid": "n3_s03156_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1], [2]]}, "draw_seed": 335870901, "tag": "n3"}, {"iid": "n3_s03176_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0, 2], []]}, "draw_seed": 337870901, "tag": "n3"}, {"iid": "n3_s03191_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1, 2], [0, 1, 2]]}, "draw_seed": 339370901, "tag": "n3"}, {"iid": "n3_s03217_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [1], [0]]}, "draw_seed": 341970901, "tag": "n3"}, {"iid": "n3_s03234_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [2], [1]]}, "draw_seed": 343670901, "tag": "n3"}, {"iid": "n3_s03259_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [0, 1, 2], [0, 1]]}, "draw_seed": 346170901, "tag": "n3"}, {"iid": "n3_s03281_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [1], [0]]}, "draw_seed": 348370901, "tag": "n3"}, {"iid": "n3_s03307_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0, 2], [0, 1]]}, "draw_seed": 350970901, "tag": "n3"}, {"iid": "n3_s03328_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [], []]}, "draw_seed": 353070901, "tag": "n3"}, {"iid": "n3_s03355_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 1], [0, 1]]}, "draw_seed": 355770901, "tag": "n3"}, {"iid": "n3_s03372_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 2], [2]]}, "draw_seed": 357470901, "tag": "n3"}, {"iid": "n3_s03396_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [], [2]]}, "draw_seed": 359870901, "tag": "n3"}, {"iid": "n3_s03411_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [1], [0, 1]]}, "draw_seed": 361370901, "tag": "n3"}, {"iid": "n3_s03435_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 2], [0, 1]]}, "draw_seed": 363770901, "tag": "n3"}, {"iid": "n3_s03449_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0, 1, 2], [0]]}, "draw_seed": 365170901, "tag": "n3"}, {"iid": "n3_s03470_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0], [1, 2]]}, "draw_seed": 367270901, "tag": "n3"}, {"iid": "n3_s03494_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [2], [1, 2]]}, "draw_seed": 369670901, "tag": "n3"}, {"iid": "n3_s03517_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0, 1, 2], [0, 2]]}, "draw_seed": 371970901, "tag": "n3"}, {"iid": "n3_s03529_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0], [0]]}, "draw_seed": 373170901, "tag": "n3"}, {"iid": "n3_s03543_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1], [0, 1, 2]]}, "draw_seed": 374570901, "tag": "n3"}, {"iid": "n3_s03570_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1, 2], [1]]}, "draw_seed": 377270901, "tag": "n3"}, {"iid": "n3_s03594_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0], [1]]}, "draw_seed": 379670901, "tag": "n3"}, {"iid": "n3_s03614_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1], [1, 2]]}, "draw_seed": 381670901, "tag": "n3"}, {"iid": "n3_s03645_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1, 2], [0, 2]]}, "draw_seed": 384770901, "tag": "n3"}, {"iid": "n3_s03674_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [0, 1], [1]]}, "draw_seed": 387670901, "tag": "n3"}, {"iid": "n3_s03699_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [1, 2], [0, 1]]}, "draw_seed": 390170901, "tag": "n3"}, {"iid": "n3_s03723_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0], [0, 1]]}, "draw_seed": 392570901, "tag": "n3"}, {"iid": "n3_s03737_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1], [0]]}, "draw_seed": 393970901, "tag": "n3"}, {"iid": "n3_s03766_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1, 2], [1, 2]]}, "draw_seed": 396870901, "tag": "n3"}, {"iid": "n3_s03781_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [], [0, 2]]}, "draw_seed": 398370901, "tag": "n3"}, {"iid": "n3_s03814_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [2], [1, 2]]}, "draw_seed": 401670901, "tag": "n3"}, {"iid": "n3_s03832_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2], []]}, "draw_seed": 403470901, "tag": "n3"}, {"iid": "n3_s03849_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0], [0]]}, "draw_seed": 405170901, "tag": "n3"}, {"iid": "n3_s03873_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [2], [0]]}, "draw_seed": 407570901, "tag": "n3"}, {"iid": "n3_s03900_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1, 2], [2]]}, "draw_seed": 410270901, "tag": "n3"}, {"iid": "n3_s03914_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0], [1]]}, "draw_seed": 411670901, "tag": "n3"}, {"iid": "n3_s03929_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1], [0]]}, "draw_seed": 413170901, "tag": "n3"}, {"iid": "n3_s03948_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 2], [2]]}, "draw_seed": 415070901, "tag": "n3"}, {"iid": "n3_s03970_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [], [1]]}, "draw_seed": 417270901, "tag": "n3"}, {"iid": "n3_s03988_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1], [2]]}, "draw_seed": 419070901, "tag": "n3"}, {"iid": "n3_s04008_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 2], []]}, "draw_seed": 421070901, "tag": "n3"}, {"iid": "n3_s04026_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1, 2], [1]]}, "draw_seed": 422870901, "tag": "n3"}, {"iid": "n3_s04038_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [], [1, 2]]}, "draw_seed": 424070901, "tag": "n3"}, {"iid": "n3_s04057_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 1], [0]]}, "draw_seed": 425970901, "tag": "n3"}, {"iid": "n3_s04079_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 1, 2]]}, "draw_seed": 428170901, "tag": "n3"}, {"iid": "named_double_self_censor_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[0], [1]]}, "draw_seed": 20278679, "tag": "named"}, {"iid": "named_mediated_mnar_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[1], [0, 1]]}, "draw_seed": 20302009, "tag": "named"}, {"iid": "named_mutual_selection_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[], [1], [0]]}, "draw_seed": 20317565, "tag": "named"}, {"iid": "named_three_var_double_self_d1", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1], [2]]}, "draw_seed": 20340895, "tag": "named"}, {"iid": "n4_r0003_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": []}, "r_parents": [[0, 1, 2], [3], [1, 2, 3], []]}, "draw_seed": 25270994, "tag": "n4"}, {"iid": "n4_r0011_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1, 2]}, "r_parents": [[0, 1, 2], [0], [1, 2], []]}, "draw_seed": 25271242, "tag": "n4"}, {"iid": "n4_r0019_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [1]}, "r_parents": [[3], [3], [1, 2], [1, 2]]}, "draw_seed": 25271490, "tag": "n4"}, {"iid": "n4_r0027_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0]}, "r_parents": [[0, 1, 2], [2, 3], [0, 1, 2, 3], [1, 2, 3]]}, "draw_seed": 25271738, "tag": "n4"}, {"iid": "n4_r0035_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1]}, "r_parents": [[1, 2], [0, 3], [0], [1, 2]]}, "draw_seed": 25271986, "tag": "n4"}, {"iid": "n4_r0043_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1, 2]}, "r_parents": [[0], [0, 3], [2], [1, 2, 3]]}, "draw_seed": 25272234, "tag": "n4"}, {"iid": "n4_r0051_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 2]}, "r_parents": [[], [0], [0, 2], [3]]}, "draw_seed": 25272482, "tag": "n4"}, {"iid": "n4_r0059_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 1, 2]}, "r_parents": [[0], [0, 3], [0], [1, 2, 3]]}, "draw_seed": 25272730, "tag": "n4"}, {"iid": "n4_r0067_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [2]}, "r_parents": [[], [3], [], [1]]}, "draw_seed": 25272978, "tag": "n4"}, {"iid": "n4_r0075_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 1, 2]}, "r_parents": [[2, 3], [0, 1], [0, 1], [0, 1, 2, 3]]}, "draw_seed": 25273226, "tag": "n4"}, {"iid": "n4_r0083_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0]}, "r_parents": [[0], [0, 2], [], [0, 2, 3]]}, "draw_seed": 25273474, "tag": "n4"}, {"iid": "n4_r0091_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[0], [3], [0, 3], [0]]}, "draw_seed": 25273722, "tag": "n4"}, {"iid": "n4_r0099_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [1]}, "r_parents": [[1], [1], [0], [1]]}, "draw_seed": 25273970, "tag": "n4"}, {"iid": "n4_r0107_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1, 2]}, "r_parents": [[3], [0, 1, 3], [], [0, 3]]}, "draw_seed": 25274218, "tag": "n4"}, {"iid": "n4_r0115_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [2]}, "r_parents": [[0, 1, 2, 3], [0, 1], [0, 1, 3], [1, 2, 3]]}, "draw_seed": 25274466, "tag": "n4"}, {"iid": "n4_r0123_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 1, 2]}, "r_parents": [[0], [3], [3], [0, 1, 2, 3]]}, "draw_seed": 25274714, "tag": "n4"}, {"iid": "n4_r0131_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[1], [2, 3], [1], [0, 1, 2, 3]]}, "draw_seed": 25274962, "tag": "n4"}, {"iid": "n4_r0139_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 2]}, "r_parents": [[1, 2], [1, 2], [1, 2], [2]]}, "draw_seed": 25275210, "tag": "n4"}, {"iid": "n4_r0147_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0]}, "r_parents": [[2], [0, 1, 3], [0, 2], [1, 3]]}, "draw_seed": 25275458, "tag": "n4"}, {"iid": "n4_r0155_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [1, 2]}, "r_parents": [[], [1, 2], [2], [0]]}, "draw_seed": 25275706, "tag": "n4"}, {"iid": "n4_r0163_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0, 1], "3": [0, 2]}, "r_parents": [[0, 1, 2, 3], [1], [], [1, 2]]}, "draw_seed": 25275954, "tag": "n4"}, {"iid": "n4_r0171_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [1]}, "r_parents": [[], [0, 1], [0, 1, 3], [0, 1, 2, 3]]}, "draw_seed": 25276202, "tag": "n4"}, {"iid": "n4_r0179_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [1, 2]}, "r_parents": [[1, 2, 3], [0, 1, 2], [1, 2, 3], [3]]}, "draw_seed": 25276450, "tag": "n4"}, {"iid": "n4_r0187_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [0, 1]}, "r_parents": [[0, 1], [0, 1, 2, 3], [0, 2], [0, 2]]}, "draw_seed": 25276698, "tag": "n4"}, {"iid": "n4_r0195_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [1]}, "r_parents": [[2, 3], [0], [1, 2], [0, 1, 2]]}, "draw_seed": 25276946, "tag": "n4"}]''')
SHARD_IDX = 7
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
