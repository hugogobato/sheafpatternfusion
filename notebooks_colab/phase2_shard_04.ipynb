# %% [markdown]
# # SheafPatternFusion Phase 2 - shard 04/8
# Jobs: 196. Code: pip-installed from hugogobato/sheafpatternfusion @ v0.2.0.
# Runtime: CPU-only. Expected wall time < 10h at ~2 cores.
#
# The second cell installs the pinned package and restarts the
# kernel once (required after upgrading numpy/scipy in place). After
# the runtime reconnects, run Runtime > Run all again.

# %%
import importlib.metadata as md
import os
import subprocess
import sys

REPO = 'https://github.com/hugogobato/sheafpatternfusion.git'
TAG = 'v0.2.0'
WANT = {'numpy': '2.4.3', 'scipy': '1.17.1', 'sheafpatternfusion': '0.2.0'}

def _ver(pkg):
    try:
        return md.version(pkg)
    except Exception:
        return None

if all(_ver(p) == v for p, v in WANT.items()):
    print('environment OK:', WANT)
else:
    print('installing sheafpatternfusion@' + TAG + ' (one-time per session) ...')
    res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                          f'git+{REPO}@{TAG}'])
    if res.returncode != 0:
        raise RuntimeError('pip install failed; see log above')
    print('installed -> restarting the kernel so the ABI-matched numpy/scipy')
    print('binaries load cleanly.')
    print('When the runtime reconnects, run Runtime > Run all again; this')
    print('cell will detect the pins and skip.')
    os.kill(os.getpid(), 9)

# %%
import json
import pathlib
GRID_CFG = json.loads(r'''{
  "description": "Phase 2 enumeration grid (WP2.1). Frozen 2026-08-24 after pilot timing.",
  "n2": {"mode": "exhaustive", "draws_per_structure": 2},
  "n3": {"mode": "stratified_random", "sampled_structures": 1400, "draws_per_structure": 1},
  "n4": {"mode": "random", "sampled_structures": 200, "draws_per_structure": 1},
  "named_classes": {"draws_per_structure": 3},
  "budgets": {
    "witness_starts": 24,
    "jump_starts": 40,
    "fiber_starts": 48,
    "max_roots": 12,
    "undecided_round2_multiplier": 2,
    "lp_pinch_tol": 1e-9,
    "lp_width_tol": 1e-3,
    "spread_tol": 1e-6
  },
  "ci_discovery_draws": 16,
  "poset_scan_families": 30,
  "section_check_draws": 4,
  "seeds": {
    "structure_seed_base_n3": 20260901,
    "structure_seed_base_n4": 20260907,
    "draw_seed_base": 20270901,
    "poset_scan_seed": 20280901,
    "content_scan_seed": 20290901
  },
  "compute": {
    "workers": 6,
    "blas_threads_per_worker": 1,
    "projected_rows": 2900,
    "pilot_wall_per_row_s": null
  }
}
''')
JOBS = json.loads(r'''[{"iid": "n3_s00215_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [1], [0, 1, 2]]}, "draw_seed": 41770901, "tag": "n3"}, {"iid": "n3_s00252_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 1], [0, 1, 2], [2]]}, "draw_seed": 45470901, "tag": "n3"}, {"iid": "n3_s00272_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [1], []]}, "draw_seed": 47470901, "tag": "n3"}, {"iid": "n3_s00288_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [2], []]}, "draw_seed": 49070901, "tag": "n3"}, {"iid": "n3_s00311_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[2], [1, 2], [0, 1, 2]]}, "draw_seed": 51370901, "tag": "n3"}, {"iid": "n3_s00335_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [0], [0, 1, 2]]}, "draw_seed": 53770901, "tag": "n3"}, {"iid": "n3_s00356_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[0, 2], [2], [2]]}, "draw_seed": 55870901, "tag": "n3"}, {"iid": "n3_s00388_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [[1, 2], [], [2]]}, "draw_seed": 59070901, "tag": "n3"}, {"iid": "n3_s00408_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [], "2": []}, "r_parents": [
d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [2], [1, 2]]}, "draw_seed": 286470901, "tag": "n3"}, {"iid": "n3_s02682_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0], [0, 1, 2], [1]]}, "draw_seed": 288470901, "tag": "n3"}, {"iid": "n3_s02720_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [2], []]}, "draw_seed": 292270901, "tag": "n3"}, {"iid": "n3_s02743_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1], [1, 2], [0, 1, 2]]}, "draw_seed": 294570901, "tag": "n3"}, {"iid": "n3_s02766_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [0], [1, 2]]}, "draw_seed": 296870901, "tag": "n3"}, {"iid": "n3_s02785_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [2], [0]]}, "draw_seed": 298770901, "tag": "n3"}, {"iid": "n3_s02803_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1], [1, 2], [0, 1]]}, "draw_seed": 300570901, "tag": "n3"}, {"iid": "n3_s02823_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [], [0, 1, 2]]}, "draw_seed": 302570901, "tag": "n3"}, {"iid": "n3_s02852_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [2], [2]]}, "draw_seed": 305470901, "tag": "n3"}, {"iid": "n3_s02875_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[2], [0, 1, 2], [0, 1]]}, "draw_seed": 307770901, "tag": "n3"}, {"iid": "n3_s02893_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [0], [0, 2]]}, "draw_seed": 309570901, "tag": "n3"}, {"iid": "n3_s02919_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [2], [0, 1, 2]]}, "draw_seed": 312170901, "tag": "n3"}, {"iid": "n3_s02943_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 2], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 314570901, "tag": "n3"}, {"iid": "n3_s02973_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [0, 1], [0, 2]]}, "draw_seed": 317570901, "tag": "n3"}, {"iid": "n3_s02997_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[1, 2], [1, 2], [0, 2]]}, "draw_seed": 319970901, "tag": "n3"}, {"iid": "n3_s03022_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [0], [1, 2]]}, "draw_seed": 322470901, "tag": "n3"}, {"iid": "n3_s03037_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0]}, "r_parents": [[0, 1, 2], [0, 1], [0, 2]]}, "draw_seed": 323970901, "tag": "n3"}, {"iid": "n3_s03078_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [], [1, 2]]}, "draw_seed": 328070901, "tag": "n3"}, {"iid": "n3_s03101_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0, 1], [0, 2]]}, "draw_seed": 330370901, "tag": "n3"}, {"iid": "n3_s03130_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[], [0, 1, 2], [1]]}, "draw_seed": 333270901, "tag": "n3"}, {"iid": "n3_s03151_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0], [0, 1, 2]]}, "draw_seed": 335370901, "tag": "n3"}, {"iid": "n3_s03163_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [0, 1], [0, 1]]}, "draw_seed": 336570901, "tag": "n3"}, {"iid": "n3_s03186_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0], [1, 2], [1]]}, "draw_seed": 338870901, "tag": "n3"}, {"iid": "n3_s03211_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [0], [0, 1]]}, "draw_seed": 341370901, "tag": "n3"}, {"iid": "n3_s03226_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [0, 1], [1]]}, "draw_seed": 342870901, "tag": "n3"}, {"iid": "n3_s03252_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1], [1, 2], [2]]}, "draw_seed": 345470901, "tag": "n3"}, {"iid": "n3_s03275_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0], [0, 1]]}, "draw_seed": 347770901, "tag": "n3"}, {"iid": "n3_s03297_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [2], [0]]}, "draw_seed": 349970901, "tag": "n3"}, {"iid": "n3_s03320_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1], [0, 1, 2], []]}, "draw_seed": 352270901, "tag": "n3"}, {"iid": "n3_s03343_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0], [0, 1, 2]]}, "draw_seed": 354570901, "tag": "n3"}, {"iid": "n3_s03366_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [2], [1, 2]]}, "draw_seed": 356870901, "tag": "n3"}, {"iid": "n3_s03389_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[2], [0, 1, 2], [0, 2]]}, "draw_seed": 359170901, "tag": "n3"}, {"iid": "n3_s03404_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [0], [2]]}, "draw_seed": 360670901, "tag": "n3"}, {"iid": "n3_s03429_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [2], [0, 2]]}, "draw_seed": 363170901, "tag": "n3"}, {"iid": "n3_s03444_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 2], [1, 2], [2]]}, "draw_seed": 364670901, "tag": "n3"}, {"iid": "n3_s03465_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [0], [0]]}, "draw_seed": 366770901, "tag": "n3"}, {"iid": "n3_s03488_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [2], []]}, "draw_seed": 369070901, "tag": "n3"}, {"iid": "n3_s03511_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[1, 2], [1, 2], [0, 1, 2]]}, "draw_seed": 371370901, "tag": "n3"}, {"iid": "n3_s03526_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [], [1, 2]]}, "draw_seed": 372870901, "tag": "n3"}, {"iid": "n3_s03539_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [1], [0, 1]]}, "draw_seed": 374170901, "tag": "n3"}, {"iid": "n3_s03563_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 1]]}, "draw_seed": 376570901, "tag": "n3"}, {"iid": "n3_s03586_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [], [1]]}, "draw_seed": 378870901, "tag": "n3"}, {"iid": "n3_s03608_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [0, 1], []]}, "draw_seed": 381070901, "tag": "n3"}, {"iid": "n3_s03639_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[], [1, 2], [0, 1, 2]]}, "draw_seed": 384170901, "tag": "n3"}, {"iid": "n3_s03666_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [1], [1]]}, "draw_seed": 386870901, "tag": "n3"}, {"iid": "n3_s03686_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0], [2], [1, 2]]}, "draw_seed": 388870901, "tag": "n3"}, {"iid": "n3_s03718_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [], [1, 2]]}, "draw_seed": 392070901, "tag": "n3"}, {"iid": "n3_s03733_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1], [0, 2]]}, "draw_seed": 393570901, "tag": "n3"}, {"iid": "n3_s03760_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [1, 2], []]}, "draw_seed": 396270901, "tag": "n3"}, {"iid": "n3_s03775_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1], [0, 1, 2], [0, 1, 2]]}, "draw_seed": 397770901, "tag": "n3"}, {"iid": "n3_s03800_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 1], []]}, "draw_seed": 400270901, "tag": "n3"}, {"iid": "n3_s03823_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1], [0, 2], [0, 1, 2]]}, "draw_seed": 402570901, "tag": "n3"}, {"iid": "n3_s03840_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [], []]}, "draw_seed": 404270901, "tag": "n3"}, {"iid": "n3_s03864_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [0, 1], []]}, "draw_seed": 406670901, "tag": "n3"}, {"iid": "n3_s03888_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[2], [1, 2], []]}, "draw_seed": 409070901, "tag": "n3"}, {"iid": "n3_s03909_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [], [0, 2]]}, "draw_seed": 411170901, "tag": "n3"}, {"iid": "n3_s03923_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [1], [0, 1]]}, "draw_seed": 412570901, "tag": "n3"}, {"iid": "n3_s03939_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [2], [0, 1]]}, "draw_seed": 414170901, "tag": "n3"}, {"iid": "n3_s03960_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 2], [0, 1, 2], []]}, "draw_seed": 416270901, "tag": "n3"}, {"iid": "n3_s03984_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1], []]}, "draw_seed": 418670901, "tag": "n3"}, {"iid": "n3_s03995_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [0, 1], [0, 1]]}, "draw_seed": 419770901, "tag": "n3"}, {"iid": "n3_s04021_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[1, 2], [1, 2], [0, 2]]}, "draw_seed": 422370901, "tag": "n3"}, {"iid": "n3_s04033_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [], [0]]}, "draw_seed": 423570901, "tag": "n3"}, {"iid": "n3_s04053_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [1], [0, 2]]}, "draw_seed": 425570901, "tag": "n3"}, {"iid": "n3_s04075_d0", "n_vars": 3, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1]}, "r_parents": [[0, 1, 2], [0, 2], [0, 1]]}, "draw_seed": 427770901, "tag": "n3"}, {"iid": "named_collider_selection_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": []}, "r_parents": [[], [0, 1]]}, "draw_seed": 20270902, "tag": "named"}, {"iid": "named_mcar_reference_d0", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], []]}, "draw_seed": 20294232, "tag": "named"}, {"iid": "named_mnar_on_partial_cause_d2", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [0]]}, "draw_seed": 20309788, "tag": "named"}, {"iid": "named_self_censor_v2_chain_d1", "n_vars": 2, "structure": {"var_parents": {"0": [], "1": [0]}, "r_parents": [[], [1]]}, "draw_seed": 20333118, "tag": "named"}, {"iid": "n4_r0000_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 2]}, "r_parents": [[0, 1], [2], [1], [0, 2]]}, "draw_seed": 25270901, "tag": "n4"}, {"iid": "n4_r0008_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [0, 1, 2]}, "r_parents": [[0, 1, 3], [0], [0, 1, 2], [1, 2]]}, "draw_seed": 25271149, "tag": "n4"}, {"iid": "n4_r0016_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1, 2]}, "r_parents": [[0, 1, 3], [0, 2, 3], [0, 2, 3], [1, 2, 3]]}, "draw_seed": 25271397, "tag": "n4"}, {"iid": "n4_r0024_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0]}, "r_parents": [[0, 1, 2, 3], [0, 2], [2, 3], [0, 2]]}, "draw_seed": 25271645, "tag": "n4"}, {"iid": "n4_r0032_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [2]}, "r_parents": [[0], [0, 3], [0, 1, 2, 3], [0, 1, 2]]}, "draw_seed": 25271893, "tag": "n4"}, {"iid": "n4_r0040_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [1]}, "r_parents": [[0, 3], [0], [0, 1, 2, 3], []]}, "draw_seed": 25272141, "tag": "n4"}, {"iid": "n4_r0048_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [1, 2]}, "r_parents": [[0, 1, 3], [0, 3], [0], [0, 1]]}, "draw_seed": 25272389, "tag": "n4"}, {"iid": "n4_r0056_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [1, 2]}, "r_parents": [[0, 1, 3], [2], [3], [1, 2, 3]]}, "draw_seed": 25272637, "tag": "n4"}, {"iid": "n4_r0064_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [0, 1, 2]}, "r_parents": [[1, 2], [2, 3], [2, 3], [0, 1]]}, "draw_seed": 25272885, "tag": "n4"}, {"iid": "n4_r0072_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": [1]}, "r_parents": [[3], [1, 2], [0, 2, 3], [0, 1]]}, "draw_seed": 25273133, "tag": "n4"}, {"iid": "n4_r0080_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [2]}, "r_parents": [[1, 2], [0], [], [0, 2, 3]]}, "draw_seed": 25273381, "tag": "n4"}, {"iid": "n4_r0088_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": []}, "r_parents": [[0, 1, 3], [1], [0], [0, 1]]}, "draw_seed": 25273629, "tag": "n4"}, {"iid": "n4_r0096_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 2]}, "r_parents": [[0, 2], [0, 1, 3], [], [0, 2, 3]]}, "draw_seed": 25273877, "tag": "n4"}, {"iid": "n4_r0104_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 1]}, "r_parents": [[0, 2, 3], [2, 3], [3], [1, 2]]}, "draw_seed": 25274125, "tag": "n4"}, {"iid": "n4_r0112_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": []}, "r_parents": [[1], [0, 1, 3], [0], [1, 3]]}, "draw_seed": 25274373, "tag": "n4"}, {"iid": "n4_r0120_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [], "3": [1]}, "r_parents": [[0, 2, 3], [0, 1], [0, 1], [2, 3]]}, "draw_seed": 25274621, "tag": "n4"}, {"iid": "n4_r0128_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 2]}, "r_parents": [[2], [0, 1, 2, 3], [1, 3], [0, 1, 2, 3]]}, "draw_seed": 25274869, "tag": "n4"}, {"iid": "n4_r0136_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0], "3": [0, 2]}, "r_parents": [[1], [0, 1, 2, 3], [1, 2], [1, 3]]}, "draw_seed": 25275117, "tag": "n4"}, {"iid": "n4_r0144_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 1]}, "r_parents": [[1, 2, 3], [1, 2], [1], [0, 2]]}, "draw_seed": 25275365, "tag": "n4"}, {"iid": "n4_r0152_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [1], "3": [0, 1]}, "r_parents": [[1, 2], [0, 2, 3], [0, 3], [0]]}, "draw_seed": 25275613, "tag": "n4"}, {"iid": "n4_r0160_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [0], "3": [1]}, "r_parents": [[2], [0, 2, 3], [2, 3], [2, 3]]}, "draw_seed": 25275861, "tag": "n4"}, {"iid": "n4_r0168_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": [0, 1]}, "r_parents": [[0, 3], [0], [1, 2, 3], [0, 1, 2, 3]]}, "draw_seed": 25276109, "tag": "n4"}, {"iid": "n4_r0176_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [1], "3": []}, "r_parents": [[3], [3], [3], [0, 1, 2, 3]]}, "draw_seed": 25276357, "tag": "n4"}, {"iid": "n4_r0184_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [0], "2": [0, 1], "3": [0, 1]}, "r_parents": [[1, 3], [1, 2, 3], [3], [2]]}, "draw_seed": 25276605, "tag": "n4"}, {"iid": "n4_r0192_d0", "n_vars": 4, "structure": {"var_parents": {"0": [], "1": [], "2": [], "3": []}, "r_parents": [[0, 3], [0, 1, 3], [0, 1], [1, 3]]}, "draw_seed": 25276853, "tag": "n4"}]''')
SHARD_IDX = 4
N_SHARDS = 8
OUT_DIR = pathlib.Path('/content/results/phase2/phase2_shards')
OUT_DIR.mkdir(parents=True, exist_ok=True)
SHARD_FILE = OUT_DIR / f'shard_{SHARD_IDX:02d}.jsonl'
done = set()
if SHARD_FILE.exists():
    for line in SHARD_FILE.read_text().splitlines():
        try:
            rec = json.loads(line)
            done.add(rec['instance_id'] + '|' + json.dumps(rec['target']))
        except Exception:
            pass
todo = [j for j in JOBS]
print(f'shard {SHARD_IDX}: {len(todo)} jobs, {len(done)} rows already on file')

# %%
# re-implement run_instance against the embedded package (no pickle,
# sequential loop: 2 cores are enough for the per-job budgets)
import os
import time

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'

import numpy as np
from sheafpatternfusion.engine2 import decide2, sheaf_fiber_verdict
from sheafpatternfusion.enumerate_structures import (
    classify, conflict_flags, discover_slice_cis, graham_acyclic,
    pick_targets, poset_shape, instantiate)
from sheafpatternfusion.gluing import marginal_problem_lp
from sheafpatternfusion.lp_ground_truth import pack, unpack

def run_one(job):
    vp = {int(k): tuple(v) for k, v in job['structure']['var_parents'].items()}
    structure = (vp, tuple(tuple(p) for p in job['structure']['r_parents']))
    inst = instantiate(structure, seed=job['draw_seed'])
    info = classify(inst)
    jt = inst.joint_table()
    patterns = inst.realized_patterns(jt=jt)
    q = inst.observed_laws(jt)
    pp = {}
    for (v, r), p in jt.items():
        pp[r] = pp.get(r, 0.0) + p
    fam_w = {r: {o: c * pp[r] for o, c in cells.items()} for r, cells in q.items()}
    completability = marginal_problem_lp(inst.n_vars, fam_w)['feasible']
    sets = [frozenset(i for i in range(inst.n_vars) if r[i] == 1) for r in patterns]
    shape = poset_shape(patterns)
    conflicts = conflict_flags(inst)
    cis = discover_slice_cis(inst, n_draws=16)
    theta_true = pack(inst)
    recs = []
    for tgt in pick_targets(inst):
        eng = decide2(inst, theta_true, tgt, seed=11)
        if eng['gt_verdict'].startswith('UNDETERMINED'):
            eng = decide2(inst, theta_true, tgt, jump_starts=90, seed=23)
            eng['gt_evidence'] = 'round2:' + eng['gt_evidence']
        fib = sheaf_fiber_verdict(inst, theta_true, tgt, n_starts=48, seed=13)
        recs.append({
            'instance_id': job['iid'], 'tag': job['tag'], 'seed': job['draw_seed'],
            'n_vars': inst.n_vars,
            'var_parents': {str(k): list(v) for k, v in vp.items()},
            'r_parents': [list(p) for p in structure[1]],
            'mechanism_class': info['mechanism_class'],
            'has_self_edge': info['has_self_edge'],
            'poset_shape': shape, 'graham_acyclic': bool(graham_acyclic(sets)),
            'n_realized_patterns': len(patterns),
            'patterns': [list(p) for p in patterns],
            'always_observed': list(info['always_observed']),
            'never_observed': list(info['never_observed']),
            'target': list(tgt), 'true_value': eng.get('true_value'),
            'gt_recoverable': eng['gt_verdict'], 'gt_evidence': eng['gt_evidence'],
            'lp_width': eng.get('lp', {}).get('width'),
            'witness_delta_phi': eng.get('witness', {}).get('delta_phi'),
            'sheaf_recoverable': fib['sheaf_verdict'],
            'phi_spread_over_fiber': fib['phi_spread_over_fiber'],
            'n_distinct_completions': fib['n_distinct_completions'],
            'jacobian_rank': fib['jacobian_rank'],
            'n_free_params': fib['n_free_params'],
            'jacobian_full_rank': bool(fib['jacobian_rank'] == fib['n_free_params']),
            'observed_family_completable': bool(completability),
            'conflict_mcar_style': conflicts['conflict_mcar_style'],
            'max_cross_pattern_marginal_gap': conflicts['max_cross_pattern_marginal_gap'],
            'n_slice_ci_constraints': int(sum(len(v) for v in cis.values())),
            'slice_cis': {''.join(map(str, r)): [list(c) for c in lst]
                          for r, lst in cis.items() if lst},
            'wall_s': None, 'shard': SHARD_IDX,
        })
    return recs

t0 = time.time()
for k, job in enumerate(todo):
    try:
        recs = run_one(job)
    except Exception as e:
        print(f'FAILED {job["iid"]}: {type(e).__name__}: {e}', flush=True)
        continue
    keys = {r['instance_id'] + '|' + json.dumps(r['target']) for r in recs}
    if keys <= done:
        continue
    with open(SHARD_FILE, 'a') as fout:
        for r in recs:
            fout.write(json.dumps(r) + '\n')
    if (k + 1) % 10 == 0:
        el = time.time() - t0
        print(f'[{k+1}/{len(todo)}] {el/60:.1f} min', flush=True)
print('SHARD DONE', flush=True)

# %%
output_file = str(SHARD_FILE)
try:
    from google.colab import files
    files.download(output_file)
    print('Downloaded:', output_file)
except Exception as e:
    print('(Not on Colab / download skipped):', e)
